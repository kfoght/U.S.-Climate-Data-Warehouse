# %%
# !pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (3.0.1)

# %%
import json
import os
import time
from pathlib import Path
import vertexai
from vertexai.generative_models import GenerativeModel, Part
from google.cloud import storage
from google.cloud.storage import transfer_manager

# Configuration
project_id = "kiaraerica"
location = "us-central1"
bucket_name = "us_climate"
raw_folder = "initial-loads/state_climate_policies/raw/"
llm_folder = "initial-loads/state_climate_policies/llm_text/"
model_name = "gemini-1.5-flash-001"

# Updated prompt for NDJSON
prompt = """Extract structured policy data from this document.
Identify and return the following fields:
1. Policy Title (only the title, without descriptions)
2. Policy Area
3. Category
4. Status (Enacted/Not Enacted)
5. Year Enacted (if available)

Return each policy as a separate JSON object, one per line (NDJSON format), like:
{"policy": "string", "policy_area": "string", "category": "string", "status": "string", "year_enacted": "string"}

Do not return an array. Do not add extra text. Return only NDJSON.
"""

def extract():
    """Extracts structured data from all PDFs in `raw_folder` using Gemini and outputs NDJSON format."""
    vertexai.init(project=project_id, location=location)
    model = GenerativeModel(model_name)

    storage_client = storage.Client()
    blobs = storage_client.list_blobs(bucket_name, prefix=raw_folder)

    for blob in blobs:
        if blob.name == raw_folder:
            continue  # Skip folder itself

        # Extract the state name from the filename
        state_name = Path(blob.name).stem  # "Alabama.pdf" → "Alabama"

        # Generate correct JSONL file path
        json_filename = Path(llm_folder) / f"{state_name}.jsonl"
        print(f"Saving NDJSON file to: {json_filename}")

        print(f"Processing {blob.name}...")  # ✅ Always process the file
        file_content = Part.from_uri(f"gs://{bucket_name}/{blob.name}", "application/pdf")
        resp = model.generate_content([file_content, prompt])

        # Remove any extraneous Markdown artifacts
        resp_text = resp.text.strip().replace("```json", "").replace("```", "")
        raw_lines = resp_text.split("\n")  # Split response line by line

        # Ensure folder exists
        json_filename.parent.mkdir(parents=True, exist_ok=True)

        valid_json_lines = []

        for line in raw_lines:
            line = line.strip()
            if not line:
                continue  # Skip empty lines

            try:
                json_obj = json.loads(line)  # Parse each line separately
                json_obj["state"] = state_name  # Add state name to JSON object
                valid_json_lines.append(json.dumps(json_obj))  # Store valid JSON strings
            except json.JSONDecodeError:
                print(f"⚠️ Skipping malformed JSON line: {line}")  # Debugging step

        if not valid_json_lines:
            print(f"❌ Error: No valid JSON extracted for {blob.name}. Skipping file.")
            continue  # Move to next file without saving invalid data

        # ✅ Overwrite existing NDJSON file
        with open(json_filename, "w", encoding="utf-8") as f:
            f.write("\n".join(valid_json_lines) + "\n")

        print(f"✅ Successfully saved NDJSON: {json_filename}")


def copy_to_GCS(local_folder, gcs_folder, file_extension):
    """Uploads all processed JSONL files to Google Cloud Storage."""
    storage_client = storage.Client()
    bucket = storage_client.bucket(bucket_name)

    directory_as_path_obj = Path(local_folder).resolve()
    print(f"Checking for JSONL files in: {directory_as_path_obj}")  # Debugging step

    file_paths = list(directory_as_path_obj.rglob(file_extension))
    print(f"Found JSONL files: {file_paths}")  # Debugging step

    if not file_paths:
        print(f"⚠️ No JSONL files found in {local_folder}, skipping upload.")
        return

    correct_gcs_folder = gcs_folder.rstrip("/") + "/"

    results = transfer_manager.upload_many_from_filenames(
        bucket,
        [str(f.relative_to(directory_as_path_obj)) for f in file_paths],
        source_directory=str(directory_as_path_obj),
        blob_name_prefix=correct_gcs_folder,
        max_workers=5
    )

    for name, result in zip(file_paths, results):
        if isinstance(result, Exception):
            print(f"⚠️ Failed to upload {name} due to {result}")
        else:
            print(f"✅ Uploaded {name} to {bucket.name}")

if __name__ == "__main__":
    extract()  # Process ALL PDFs and convert to NDJSON
    copy_to_GCS(llm_folder, llm_folder, "*.jsonl")  # Upload ALL JSONL files
# Out:
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Alabama.jsonl
# Processing initial-loads/state_climate_policies/raw/Alabama.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Alabama.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Alaska.jsonl
# Processing initial-loads/state_climate_policies/raw/Alaska.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Alaska.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Arizona.jsonl
# Processing initial-loads/state_climate_policies/raw/Arizona.pdf...
# ⚠️ Skipping malformed JSON line: ==End of OCR for page 11==
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Arizona.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Arkansas.jsonl
# Processing initial-loads/state_climate_policies/raw/Arkansas.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Arkansas.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/California.jsonl
# Processing initial-loads/state_climate_policies/raw/California.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/California.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Colorado.jsonl
# Processing initial-loads/state_climate_policies/raw/Colorado.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Colorado.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Connecticut.jsonl
# Processing initial-loads/state_climate_policies/raw/Connecticut.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Connecticut.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Delaware.jsonl
# Processing initial-loads/state_climate_policies/raw/Delaware.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Delaware.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Florida.jsonl
# Processing initial-loads/state_climate_policies/raw/Florida.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Florida.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Georgia.jsonl
# Processing initial-loads/state_climate_policies/raw/Georgia.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Georgia.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Hawai‘i.jsonl
# Processing initial-loads/state_climate_policies/raw/Hawai‘i.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Hawai‘i.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Idaho.jsonl
# Processing initial-loads/state_climate_policies/raw/Idaho.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Idaho.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Illinois.jsonl
# Processing initial-loads/state_climate_policies/raw/Illinois.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Illinois.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Indiana.jsonl
# Processing initial-loads/state_climate_policies/raw/Indiana.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Indiana.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Iowa.jsonl
# Processing initial-loads/state_climate_policies/raw/Iowa.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Iowa.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Kansas.jsonl
# Processing initial-loads/state_climate_policies/raw/Kansas.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Kansas.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Kentucky.jsonl
# Processing initial-loads/state_climate_policies/raw/Kentucky.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Kentucky.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Louisiana.jsonl
# Processing initial-loads/state_climate_policies/raw/Louisiana.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Louisiana.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Maine.jsonl
# Processing initial-loads/state_climate_policies/raw/Maine.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Maine.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Maryland.jsonl
# Processing initial-loads/state_climate_policies/raw/Maryland.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Maryland.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Massachusetts.jsonl
# Processing initial-loads/state_climate_policies/raw/Massachusetts.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Massachusetts.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Michigan.jsonl
# Processing initial-loads/state_climate_policies/raw/Michigan.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Michigan.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Minnesota.jsonl
# Processing initial-loads/state_climate_policies/raw/Minnesota.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Minnesota.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Mississippi.jsonl
# Processing initial-loads/state_climate_policies/raw/Mississippi.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Mississippi.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Missouri.jsonl
# Processing initial-loads/state_climate_policies/raw/Missouri.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Missouri.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Montana.jsonl
# Processing initial-loads/state_climate_policies/raw/Montana.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Montana.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Nebraska.jsonl
# Processing initial-loads/state_climate_policies/raw/Nebraska.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Nebraska.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Nevada.jsonl
# Processing initial-loads/state_climate_policies/raw/Nevada.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Nevada.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/New Hampshire.jsonl
# Processing initial-loads/state_climate_policies/raw/New Hampshire.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/New Hampshire.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/New Jersey.jsonl
# Processing initial-loads/state_climate_policies/raw/New Jersey.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/New Jersey.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/New Mexico.jsonl
# Processing initial-loads/state_climate_policies/raw/New Mexico.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/New Mexico.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/New York.jsonl
# Processing initial-loads/state_climate_policies/raw/New York.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/New York.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/North Carolina.jsonl
# Processing initial-loads/state_climate_policies/raw/North Carolina.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/North Carolina.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/North Dakota.jsonl
# Processing initial-loads/state_climate_policies/raw/North Dakota.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/North Dakota.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Ohio.jsonl
# Processing initial-loads/state_climate_policies/raw/Ohio.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Ohio.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Oklahoma.jsonl
# Processing initial-loads/state_climate_policies/raw/Oklahoma.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Oklahoma.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Oregon.jsonl
# Processing initial-loads/state_climate_policies/raw/Oregon.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Oregon.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Pennsylvania.jsonl
# Processing initial-loads/state_climate_policies/raw/Pennsylvania.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Pennsylvania.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Rhode Island.jsonl
# Processing initial-loads/state_climate_policies/raw/Rhode Island.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Rhode Island.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/South Carolina.jsonl
# Processing initial-loads/state_climate_policies/raw/South Carolina.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/South Carolina.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/South Dakota.jsonl
# Processing initial-loads/state_climate_policies/raw/South Dakota.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/South Dakota.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Tennessee.jsonl
# Processing initial-loads/state_climate_policies/raw/Tennessee.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Tennessee.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Texas.jsonl
# Processing initial-loads/state_climate_policies/raw/Texas.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Texas.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Utah.jsonl
# Processing initial-loads/state_climate_policies/raw/Utah.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Utah.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Vermont.jsonl
# Processing initial-loads/state_climate_policies/raw/Vermont.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Vermont.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Virginia.jsonl
# Processing initial-loads/state_climate_policies/raw/Virginia.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Virginia.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Washington.jsonl
# Processing initial-loads/state_climate_policies/raw/Washington.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Washington.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/West Virginia.jsonl
# Processing initial-loads/state_climate_policies/raw/West Virginia.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/West Virginia.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Wisconsin.jsonl
# Processing initial-loads/state_climate_policies/raw/Wisconsin.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Wisconsin.jsonl
# Saving NDJSON file to: initial-loads/state_climate_policies/llm_text/Wyoming.jsonl
# Processing initial-loads/state_climate_policies/raw/Wyoming.pdf...
# ✅ Successfully saved NDJSON: initial-loads/state_climate_policies/llm_text/Wyoming.jsonl
# Checking for JSONL files in: /content/initial-loads/state_climate_policies/llm_text
# Found JSONL files: [PosixPath('/content/initial-loads/state_climate_policies/llm_text/Mississippi.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Alabama.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Hawai‘i.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Kansas.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Idaho.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Oregon.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Louisiana.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Alaska.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Rhode Island.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Utah.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Oklahoma.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Indiana.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Florida.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Minnesota.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/California.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/New Hampshire.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Michigan.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Vermont.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/South Carolina.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Nevada.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Wyoming.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/New Jersey.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/North Dakota.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Maine.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Pennsylvania.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/South Dakota.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Iowa.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/North Carolina.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Massachusetts.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Georgia.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Ohio.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Connecticut.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/New York.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Colorado.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Delaware.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Texas.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Wisconsin.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Missouri.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Tennessee.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Nebraska.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/West Virginia.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Maryland.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Montana.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/New Mexico.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Illinois.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Washington.jsonl'), PosixPath('/content/initial-loads/state_climate_policies/llm_text/Arizona.jsonl'), PosixPath ...
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Mississippi.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Alabama.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Hawai‘i.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Kansas.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Idaho.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Oregon.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Louisiana.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Alaska.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Rhode Island.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Utah.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Oklahoma.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Indiana.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Florida.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Minnesota.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/California.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/New Hampshire.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Michigan.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Vermont.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/South Carolina.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Nevada.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Wyoming.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/New Jersey.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/North Dakota.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Maine.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Pennsylvania.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/South Dakota.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Iowa.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/North Carolina.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Massachusetts.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Georgia.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Ohio.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Connecticut.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/New York.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Colorado.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Delaware.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Texas.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Wisconsin.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Missouri.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Tennessee.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Nebraska.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/West Virginia.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Maryland.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Montana.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/New Mexico.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Illinois.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Washington.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Arizona.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Arkansas.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Virginia.jsonl to us_climate
# ✅ Uploaded /content/initial-loads/state_climate_policies/llm_text/Kentucky.jsonl to us_climate
