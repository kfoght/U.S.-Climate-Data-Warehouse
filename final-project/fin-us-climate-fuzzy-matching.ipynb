# %% [markdown]
# ## Final Project: Fuzzy matching of organization names

# %%
project_id = "kiaraerica"
dataset = "us_climate_fin"
region = "us-central1"
connection_id = "vertex-connection"
embedding_model = "text-embedding-005"
gemini_model = "gemini-2.5-flash-preview-04-17"

# %% [markdown]
# ### Part 1: Setup

# %% [markdown]
# ##### Create the BQ datasets

# %%
from google.cloud import bigquery

bq_client = bigquery.Client()

dataset_id = bigquery.Dataset(f"{project_id}.{dataset}")
dataset_id.location = region
resp = bq_client.create_dataset(dataset_id, exists_ok=True)
print("Created dataset {}.{}".format(bq_client.project, resp.dataset_id))
# Out:
# Created dataset kiaraerica.us_climate_fin

# %% [markdown]
# ##### Create a connection resource and register the latest embeddings model (`text-embedding-005`)

# %%
# !bq mk --connection --location=$region --project_id=$project_id \
    --connection_type=CLOUD_RESOURCE $connection_id
# Out:
# BigQuery error in mk operation: Already Exists: Connection projects/3758592633/locations/us-
# central1/connections/vertex-connection

# %%
# !bq show --connection 3758592633.us-central1.vertex-connection
# Out:
# Connection 3758592633.us-central1.vertex-connection
#
#                     name                     friendlyName   description    Last modified         type        hasCredential                                           properties
#  ------------------------------------------ -------------- ------------- ----------------- ---------------- --------------- ---------------------------------------------------------------------------------------------
#   3758592633.us-central1.vertex-connection                                20 Apr 22:11:01   CLOUD_RESOURCE   False           {"serviceAccountId": "bqcx-3758592633-7h5b@gcp-sa-bigquery-condel.iam.gserviceaccount.com"}

# %%
# !gcloud projects add-iam-policy-binding $project_id --member='serviceAccount:bqcx-3758592633-7h5b@gcp-sa-bigquery-condel.iam.gserviceaccount.com' \
  --role='roles/aiplatform.user' --no-user-output-enabled

# %% [markdown]
# ##### Replace the dataset, project, and connection as appropriate before running the next cell.

# %%
# %%bigquery
# CREATE OR REPLACE MODEL us_climate_fin.embedding_model
# REMOTE WITH CONNECTION `projects/kiaraerica/locations/us-central1/connections/vertex-connection`
# OPTIONS (endpoint = 'text-embedding-005')
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Part 2: Sample the input data, `us_climate_stg.facility_ghg_emissions`

# %%
# %%bigquery
# create or replace table us_climate_fin.ghg_facilities_no_org as
# WITH ranked as (
#   select
#       facility_id,
#       facility_name,
#       city,
#       state,
#       naics_code,
#       industry_sector1,
#       industry_sector2,
#       industry_sector3,
#       max_rated_heat_input_capacity,
#       carbon_dioxide_emissions,
#       methane_emissions,
#       nitrous_oxide_emissions,
#       biogenic_co2_emissions,
#       _data_source,
#       _load_time,
#       row_number() over (partition by facility_id order by _load_time desc) as rk
#   from us_climate_stg.facility_ghg_emissions
#   where facility_name is not null
# )
# select *
# from ranked
# where rk = 1
# order by facility_name
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
import json
import time
import pandas as pd
import pandas_gbq
from google.cloud import bigquery
import vertexai
from vertexai.generative_models import GenerativeModel
from google.api_core.exceptions import GoogleAPIError

vertexai.init(project=project_id, location=region)
model = GenerativeModel(model_name=gemini_model)
bq_client = bigquery.Client(project=project_id)

sql_create_checkpoint = """
CREATE TABLE IF NOT EXISTS us_climate_fin.ghg_facilities_llm_org_checkpoint (
    facility_id STRING,
    organization_name STRING
);
"""
bq_client.query(sql_create_checkpoint).result()
print("Checkpoint table is ready.")

sql_ghg = """
WITH all_facilities AS (
    SELECT
        CAST(facility_id AS STRING) AS facility_id,
        facility_name,
        city,
        state,
        naics_code,
        industry_sector1,
        industry_sector2,
        industry_sector3
    FROM us_climate_fin.ghg_facilities_no_org
    ORDER BY facility_id
),
unprocessed_facilities AS (
    SELECT a.*
    FROM all_facilities a
    LEFT JOIN us_climate_fin.ghg_facilities_llm_org_checkpoint c
    ON a.facility_id = c.facility_id
    WHERE c.facility_id IS NULL
)
SELECT * FROM unprocessed_facilities
"""
df_ghg = bq_client.query(sql_ghg).to_dataframe()
print(f"Found {len(df_ghg)} unprocessed facilities.")

prompt_ghg = """Given a facility from the GHG emissions dataset:
facility_id, facility_name, city, state, naics_code, industry_sector1,2,3.

Identify the organization that owns or operates this facility, or return null if unknown.
Return EXACTLY one JSON line:
{
  "facility_id": <string>,
  "organization_name": <string or null>
}
No extra text or explanation.
"""

def find_org_for_ghg(row):
    row_dict = row.to_dict()

    row_text = (
        f"facility_id={row_dict.get('facility_id', 'Unknown')}, "
        f"facility_name='{row_dict.get('facility_name', 'Unknown')}', "
        f"city='{row_dict.get('city', 'Unknown')}', "
        f"state='{row_dict.get('state', 'Unknown')}', "
        f"naics_code='{row_dict.get('naics_code', 'Unknown')}', "
        f"sector1='{row_dict.get('industry_sector1', 'Unknown')}', "
        f"sector2='{row_dict.get('industry_sector2', 'Unknown')}', "
        f"sector3='{row_dict.get('industry_sector3', 'Unknown')}'"
    )

    combined_prompt = row_text + "\n" + prompt_ghg

    try:
        resp = model.generate_content(combined_prompt)
        raw_text = resp.text.replace("```json", "").replace("```", "").strip()
        parsed = json.loads(raw_text)

        if "facility_id" not in parsed:
            parsed["facility_id"] = row_dict.get("facility_id", None)
        return parsed

    except Exception as e:
        print(f"Error processing facility_id {row_dict.get('facility_id', None)}: {e}")
        return {
            "facility_id": row_dict.get("facility_id", None),
            "organization_name": None
        }

batch_size = 50
min_batch_size = 5
sleep_time = 5
max_retries = 5

results_ghg = []
i = 0

while i < len(df_ghg):
    try:
        batch_df = df_ghg.iloc[i:i + batch_size]
        batch_results = [find_org_for_ghg(row) for _, row in batch_df.iterrows()]

        df_batch = pd.DataFrame(batch_results)
        pandas_gbq.to_gbq(
            df_batch,
            "us_climate_fin.ghg_facilities_llm_org_checkpoint",
            project_id=project_id,
            if_exists="append"
        )

        results_ghg.extend(batch_results)
        i += batch_size
        print(f"Processed {i}/{len(df_ghg)} records.")

        time.sleep(sleep_time)

    except GoogleAPIError as e:
        print(f"Quota error encountered: {e}. Retrying with backoff...")

        for retry in range(1, max_retries + 1):
            time.sleep(sleep_time * retry)
            print(f"Retrying (attempt {retry}/{max_retries})...")
            try:
                batch_df = df_ghg.iloc[i:i + batch_size]
                batch_results = [find_org_for_ghg(row) for _, row in batch_df.iterrows()]

                df_batch = pd.DataFrame(batch_results)
                pandas_gbq.to_gbq(
                    df_batch,
                    "us_climate_fin.ghg_facilities_llm_org_checkpoint",
                    project_id=project_id,
                    if_exists="append"
                )

                results_ghg.extend(batch_results)
                i += batch_size
                print(f"Processed {i}/{len(df_ghg)} records after retry.")

                break

            except GoogleAPIError:
                if retry == max_retries:
                    print("Max retries reached. Reducing batch size.")
                    batch_size = max(batch_size // 2, min_batch_size)
                    if batch_size == min_batch_size:
                        print("Minimum batch size reached. Exiting.")
                        break

df_ghg_out = pd.DataFrame(results_ghg)
pandas_gbq.to_gbq(
    df_ghg_out,
    "us_climate_fin.ghg_facilities_llm_org",
    project_id=project_id,
    if_exists="replace"
)

print("LLM results for GHG saved to ghg_facilities_llm_org.")
# Out:
# Checkpoint table is ready.
# Found 0 unprocessed facilities.
# LLM results for GHG saved to ghg_facilities_llm_org.

# %% [markdown]
# ### Part 3: Create the embeddings

# %%
# %%bigquery
#
# CREATE OR REPLACE TABLE us_climate_fin.ghg_org_names_raw AS
# SELECT DISTINCT organization_name
# FROM us_climate_fin.ghg_facilities_llm_org_checkpoint
# WHERE organization_name IS NOT NULL AND TRIM(organization_name) != ''
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#
# CREATE OR REPLACE TABLE us_climate_fin.ghg_org_embeddings AS (
#
# WITH org_content AS (
#   SELECT
#     organization_name,
#     organization_name AS content
#   FROM
#     us_climate_fin.ghg_org_names_raw
# )
#
# SELECT
#   organization_name,
#   content,
#   ml_generate_embedding_result AS embedding
# FROM
#   ML.GENERATE_EMBEDDING(
#     MODEL us_climate_fin.embedding_model,
#     (
#       SELECT organization_name, content
#       FROM org_content
#       WHERE content IS NOT NULL
#     ),
#     STRUCT('CLUSTERING' AS task_type)
#   )
# )
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# SELECT *
# FROM us_climate_fin.ghg_org_embeddings
# LIMIT 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                     organization_name                             content  \
# 0  Deseret Power Electric Cooperative  Deseret Power Electric Cooperative
# 1         Greenleaf Energy Unit 1 LLC         Greenleaf Energy Unit 1 LLC
# 2                           JSW Steel                           JSW Steel
# 3                  KAAPA Ethanol, LLC                  KAAPA Ethanol, LLC
# 4   Algonquin Power & Utilities Corp.   Algonquin Power & Utilities Corp.
# 5                 DAKOTA ETHANOL, LLC                 DAKOTA ETHANOL, LLC
# 6                 The Andersons, Inc.                 The Andersons, Inc.
# 7    Consolidated Natural Gas Company    Consolidated Natural Gas Company
# 8             Niagara Generation, LLC             Niagara Generation, LLC
# 9           NutraSweet Holdings, Inc.           NutraSweet Holdings, Inc.
#
#                                            embedding
# 0  [-0.05413160100579262, 0.035167302936315536, -...
# 1  [-0.10558508336544037, 0.007354965899139643, -...
# 2  [0.004947439301759005, 0.017695395275950432, -...
# 3  [-0.04476097226142883, 0.04654958099126816, -0...
# 4  [-0.0699002742767334, 0.013775769621133804, -0...
# 5  [-0.03983362019062042, 0.01606786996126175, -0...
# 6  [-0.058520857244729996, -0.023989615961909294,...
# 7  [-0.09865348041057587, -0.0037647339049726725,...
# 8  [-0.07392047345638275, -0.006972586736083031, ...
# 9  [-0.05890120193362236, -0.034589651972055435, ...

# %% [markdown]
# #### Part 4: Find the nearest neighbors based on cosine distance

# %%
# %%bigquery
#
# CREATE OR REPLACE TABLE us_climate_fin.ghg_org_nearest_neighbors AS
#
# SELECT
#   query.organization_name AS organization_name,
#   base.organization_name AS nearest_neighbor,
#   distance
# FROM
#   VECTOR_SEARCH(
#     TABLE us_climate_fin.ghg_org_embeddings,
#     'embedding',
#     TABLE us_climate_fin.ghg_org_embeddings,
#     'embedding',
#     TOP_K => 2,
#     DISTANCE_TYPE => 'COSINE'
#   )
# WHERE
#   query.organization_name != base.organization_name
# ORDER BY
#   distance
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
#
# SELECT *
# FROM us_climate_fin.ghg_org_nearest_neighbors
# ORDER BY distance
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                 organization_name                 nearest_neighbor  distance
# 0           EPL Oil and Gas, Inc.              EPL Oil & Gas, Inc.  0.001325
# 1             EPL Oil & Gas, Inc.            EPL Oil and Gas, Inc.  0.001325
# 2             Analog Devices Inc.             Analog Devices, Inc.  0.001820
# 3            Analog Devices, Inc.              Analog Devices Inc.  0.001820
# 4     K.P. Kauffman Company, Inc.     K. P. Kauffman Company, Inc.  0.001905
# ...                           ...                              ...       ...
# 3845                      CenTrio              Central Bi-Products  0.444565
# 3846                       Didion                           DuPont  0.455011
# 3847      Order of Saint Benedict                     OCI Beaumont  0.457049
# 3848     Architect of the Capitol  General Services Administration  0.481078
# 3849                     Lifespan                             POET  0.484093
#
# [3850 rows x 3 columns]

# %% [markdown]
# ####This was a real duplicate.
# The only difference is abbreviation ("CO." vs "COMPANY") but refers to the same entity.

# %%
# %%bigquery
# select *
# from us_climate_fin.ghg_org_nearest_neighbors
# where organization_name in ("ONEOK FIELD SERVICES CO., LLC", "ONEOK FIELD SERVICES COMPANY, LLC")
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                    organization_name                   nearest_neighbor  \
# 0      ONEOK FIELD SERVICES CO., LLC  ONEOK FIELD SERVICES COMPANY, LLC
# 1  ONEOK FIELD SERVICES COMPANY, LLC      ONEOK FIELD SERVICES CO., LLC
#
#    distance
# 0  0.004529
# 1  0.004529

# %% [markdown]
# #### This was a real duplicate.
# "Inc." and "Incorporated" are stylistic variations.

# %%
# %%bigquery
# select *
# from us_climate_fin.ghg_org_nearest_neighbors
# where organization_name in ("Leggett & Platt, Incorporated", "Leggett & Platt, Inc.")
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                organization_name               nearest_neighbor  distance
# 0  Leggett & Platt, Incorporated          Leggett & Platt, Inc.   0.00605
# 1          Leggett & Platt, Inc.  Leggett & Platt, Incorporated   0.00605

# %% [markdown]
# #### This was a real duplicate.
# Dropped "Incorporated", but they refer to the same company.

# %%
# %%bigquery
# select *
# from us_climate_fin.ghg_org_nearest_neighbors
# where organization_name in ("Texas Instruments Incorporated", "Texas Instruments")
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                 organization_name                nearest_neighbor  distance
# 0  Texas Instruments Incorporated               Texas Instruments  0.019594
# 1               Texas Instruments  Texas Instruments Incorporated  0.019594

# %% [markdown]
# #### This was a real duplicate.
# Same county name, just reversed phrasing.

# %%
# %%bigquery
# select *
# from us_climate_fin.ghg_org_nearest_neighbors
# where organization_name in ("Jackson County", "County of Jackson")
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#    organization_name   nearest_neighbor  distance
# 0     Jackson County  County of Jackson  0.073705
# 1  County of Jackson     Jackson County  0.073705

# %% [markdown]
# #### This was a real duplicate.
# Minor typo or variation ("BCC" vs "BC") but contextually the same.

# %%
# %%bigquery
# select *
# from us_climate_fin.ghg_org_nearest_neighbors
# where organization_name in ("BCC Operating, LLC", "BC Operating, Inc.")
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     organization_name    nearest_neighbor  distance
# 0  BCC Operating, LLC  BC Operating, Inc.  0.078012
# 1  BC Operating, Inc.  BCC Operating, LLC  0.078012

# %% [markdown]
# #### This was not a duplicate.
# They are two different universities in Mississippi.

# %%
# %%bigquery
# select *
# from us_climate_fin.ghg_org_nearest_neighbors
# where organization_name in ("University of Mississippi", "Mississippi State University")
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#               organization_name              nearest_neighbor  distance
# 0     University of Mississippi  Mississippi State University  0.079382
# 1  Mississippi State University     University of Mississippi  0.079382

# %% [markdown]
# #### This was not a duplicate.
# Completely different universities.

# %%
# %%bigquery
# select *
# from us_climate_fin.ghg_org_nearest_neighbors
# where organization_name in ("New Mexico State University", "University of New Mexico")
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#              organization_name          nearest_neighbor  distance
# 0  New Mexico State University  UNIVERSITY OF NEW MEXICO  0.087637

# %% [markdown]
# #### This was not a duplicate.
# Different counties.

# %%
# %%bigquery
# select *
# from us_climate_fin.ghg_org_nearest_neighbors
# where organization_name in ("Prince George's County", "Prince William County")
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#         organization_name        nearest_neighbor  distance
# 0  Prince George's County   Prince William County  0.092238
# 1   Prince William County  Prince George's County  0.092238

# %% [markdown]
# #### A reasonable cutoff would be distance <= 0.075 to filter high-confidence duplicates.

# %%
# %%bigquery
# select *
# from us_climate_fin.ghg_org_nearest_neighbors
# where distance <= 0.075
# order by distance
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                  organization_name              nearest_neighbor  distance
# 0            EPL Oil and Gas, Inc.           EPL Oil & Gas, Inc.  0.001325
# 1              EPL Oil & Gas, Inc.         EPL Oil and Gas, Inc.  0.001325
# 2              Analog Devices Inc.          Analog Devices, Inc.  0.001820
# 3             Analog Devices, Inc.           Analog Devices Inc.  0.001820
# 4      K.P. Kauffman Company, Inc.  K. P. Kauffman Company, Inc.  0.001905
# ...                            ...                           ...       ...
# 1187                    PACIFICORP                    PacifiCorp  0.074906
# 1188                    PacifiCorp                    PACIFICORP  0.074906
# 1189  LG&E and KU Services Company        LG&E and KU Energy LLC  0.074951
# 1190        LG&E and KU Energy LLC  LG&E and KU Services Company  0.074951
# 1191     OKLAHOMA STATE UNIVERSITY        UNIVERSITY OF OKLAHOMA  0.074962
#
# [1192 rows x 3 columns]

# %% [markdown]
# ### Part 5: Assign unique cluster ids to the pairs of nearest neighbors which fall within our distance threshold (<= 0.075)

# %%
import pandas as pd
import pandas_gbq
from google.cloud import bigquery

input_table = "us_climate_fin.ghg_org_nearest_neighbors"
output_table = "us_climate_fin.ghg_org_clusters"

base_query = f"""
    SELECT organization_name, nearest_neighbor
    FROM `{input_table}`
    WHERE distance <= 0.075
"""

bq_client = bigquery.Client()
rows = bq_client.query(base_query).result()

cluster_id = 0
output_clusters = []
unique_ids = set()

for row in rows:
    id1 = row["organization_name"]
    id2 = row["nearest_neighbor"]

    if id1 not in unique_ids and id2 not in unique_ids:
        cluster_id += 1
        output_clusters.append((id1, cluster_id))
        output_clusters.append((id2, cluster_id))
        unique_ids.add(id1)
        unique_ids.add(id2)
        print(f"Assigned {id1} and {id2} to cluster {cluster_id}")

df = pd.DataFrame(output_clusters, columns=["organization_name", "cluster_id"])
pandas_gbq.to_gbq(df, output_table, project_id="kiaraerica", if_exists="replace")
# Out:
# Assigned EPL Oil and Gas, Inc. and EPL Oil & Gas, Inc. to cluster 1
# Assigned Analog Devices Inc. and Analog Devices, Inc. to cluster 2
# Assigned K.P. Kauffman Company, Inc. and K. P. Kauffman Company, Inc. to cluster 3
# Assigned Neenah Paper Inc. and Neenah Paper, Inc. to cluster 4
# Assigned PPG Industries, Inc and PPG Industries, Inc. to cluster 5
# Assigned Oklahoma Gas & Electric Co. and Oklahoma Gas and Electric Co. to cluster 6
id
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                   organization_name  cluster_id
# 0             EPL Oil and Gas, Inc.           1
# 1               EPL Oil & Gas, Inc.           1
# 2               Analog Devices Inc.           2
# 3              Analog Devices, Inc.           2
# 4       K.P. Kauffman Company, Inc.           3
# ...                             ...         ...
# 1015  Western Washington University         508
# 1016                     PACIFICORP         509
# 1017                     PacifiCorp         509
# 1018   LG&E and KU Services Company         510
# 1019         LG&E and KU Energy LLC         510
#
# [1020 rows x 2 columns]

# %% [markdown]
# ### Part 6: Ask the LLM to determine which organization name to keep

# %%
# %%bigquery
# create or replace table us_climate_fin.org_filtered_practice as
#   select * from us_climate_fin.ghg_org_clusters where cluster_id in (1, 393)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Creating small example first for LLM, since some clusters do not refer to the same entity, like `cluster_id` 393.

# %%
# %%bigquery
# select * from us_climate_fin.org_filtered_practice
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#        organization_name  cluster_id
# 0    EPL Oil & Gas, Inc.           1
# 1  EPL Oil and Gas, Inc.           1
# 2  Utah State University         393
# 3     University of Utah         393

# %% [markdown]
# Checking LLM with small example

# %%
import json, pandas, pandas_gbq
from google.cloud import bigquery
import vertexai
from vertexai.generative_models import GenerativeModel

prompt = """Please verify each organization name.
If they refer to the same entity, return the most accurate organization name in json using the schema {"organization_name" : string}.
For example, {"organization_name": "EPL Oil & Gas, Inc."}
If they refer to different entities, return both organization names in json using the schema
[{"organization_name": "<name1>"}, {"organization_name": "<name2>"}]
For example, [{"organization_name": "University of Utah"}, {"organization_name": "Utah State University"}]
Do not include an explanation with your answer.
"""

sql = """select organization_name, cluster_id
from us_climate_fin.org_filtered_practice
order by cluster_id
"""

def do_inference(input_str):

    print("enter do_inference()")
    print("input_str:", input_str)

    vertexai.init(project=project_id, location=region)
    model = GenerativeModel(gemini_model)
    resp = model.generate_content([input_str, prompt])

    resp_text = resp.text.replace("```json", "").replace("```", "").replace("\n", "")
    print("resp_text:", resp_text)

    results = json.loads(resp_text)

    return results

bq_client = bigquery.Client()
rows = bq_client.query_and_wait(sql)

org_name_pairs_list = []
cluster_id = ""
prev_cluster_id = ""
combined_results = []

for row in rows:

    cluster_id = row['cluster_id']

    row_dict = {}
    row_dict["organization_name"] = row['organization_name']

    org_name_pairs_list.append(json.dumps(row_dict))

    if cluster_id == prev_cluster_id:
        org_name_pairs_str = ",".join(org_name_pairs_list)
        results = do_inference(org_name_pairs_str)
        if isinstance(results, list):
          combined_results.extend(results)
        else:
          combined_results.append(results)
        print(results)
        org_name_pairs_list.clear()

    prev_cluster_id = cluster_id

# write results to BQ
print("combined_results:", combined_results)
df = pandas.DataFrame(combined_results)
# Out:
# enter do_inference()
# input_str: {"organization_name": "EPL Oil & Gas, Inc."},{"organization_name": "EPL Oil and Gas, Inc."}
# resp_text: {"organization_name": "EPL Oil & Gas, Inc."}
# {'organization_name': 'EPL Oil & Gas, Inc.'}
# enter do_inference()
# input_str: {"organization_name": "Utah State University"},{"organization_name": "University of Utah"}
# resp_text: [{"organization_name": "Utah State University"}, {"organization_name": "University of Utah"}]
# [{'organization_name': 'Utah State University'}, {'organization_name': 'University of Utah'}]
# combined_results: [{'organization_name': 'EPL Oil & Gas, Inc.'}, {'organization_name': 'Utah State University'}, {'organization_name': 'University of Utah'}]

# %% [markdown]
# Use whole table now

# %%
import json, pandas, pandas_gbq
from google.cloud import bigquery
import vertexai
from vertexai.generative_models import GenerativeModel

prompt = """Please verify each organization name.
If they are under the same parent organization, return the closest to the parent organization name in json using the schema {"organization_name" : string}.
For example, {"organization_name": "EPL Oil & Gas, Inc."}
If they refer to different parent organizations, return both organization names in json using the schema
[{"organization_name": "<name1>"}, {"organization_name": "<name2>"}]
For example, [{"organization_name": "University of Utah"}, {"organization_name": "Utah State University"}]
Do not include an explanation with your answer.
"""

sql_create_checkpoint = """
create table if not exists us_climate_fin.cluster_checkpoint (
    cluster_id integer,
)
"""
bq_client = bigquery.Client()
bq_client.query(sql_create_checkpoint).result()
print("Checkpoint table is ready.")

sql = """select organization_name, cluster_id
from us_climate_fin.ghg_org_clusters
where cluster_id not in (
  select cluster_id from us_climate_fin.cluster_checkpoint
)
order by cluster_id
"""

def do_inference(input_str):

    print("enter do_inference()")
    print("input_str:", input_str)

    vertexai.init(project=project_id, location=region)
    model = GenerativeModel(gemini_model)
    resp = model.generate_content([input_str, prompt])

    resp_text = resp.text.replace("```json", "").replace("```", "").replace("\n", "")
    print("resp_text:", resp_text)

    results = json.loads(resp_text)

    if isinstance(results, dict):
      return [results]

    return results

rows = bq_client.query_and_wait(sql)

org_name_pairs_list = []
cluster_id = ""
prev_cluster_id = ""
combined_results = []
results_table = "us_climate_fin.ghg_org_name_filtered"
checkpoint_table = "us_climate_fin.cluster_checkpoint"

for row in rows:

    cluster_id = row['cluster_id']

    row_dict = {}
    row_dict["organization_name"] = row['organization_name']

    org_name_pairs_list.append(json.dumps(row_dict))

    if cluster_id == prev_cluster_id:
        org_name_pairs_str = ",".join(org_name_pairs_list)
        results = do_inference(org_name_pairs_str)

        for r in results:
          r["cluster_id"] = cluster_id

        combined_results.extend(results)
        print(results)
        org_name_pairs_list.clear()

        checkpoint_query = f"""
        insert into `{checkpoint_table}` (cluster_id)
        values ({cluster_id})
        """
        bq_client.query(checkpoint_query).result()

        if len(combined_results) >= 50:
            df = pandas.DataFrame(combined_results)
            pandas_gbq.to_gbq(df, results_table, project_id=project_id, if_exists="append")
            combined_results.clear()

    prev_cluster_id = cluster_id

if combined_results:
    df = pandas.DataFrame(combined_results)
    pandas_gbq.to_gbq(df, results_table, project_id=project_id, if_exists="append")

#         if isinstance(results, list):
#           combined_results.extend(results)
#         else:
#           combined_results.append(results)
#         print(results)
#         org_name_pairs_list.clear()

#     prev_cluster_id = cluster_id

# # write results to BQ
# print("combined_results:", combined_results)
# df = pandas.DataFrame(combined_results)

# table_id = "us_climate_fin.organization_name_filtered" # output table
# pandas_gbq.to_gbq(df, table_id, project_id=project_id, if_exists="replace")
# Out:
# Checkpoint table is ready.
# enter do_inference()
# input_str: {"organization_name": "EPL Oil and Gas, Inc."},{"organization_name": "EPL Oil & Gas, Inc."}
# resp_text: {"organization_name": "EPL Oil & Gas, Inc."}
# [{'organization_name': 'EPL Oil & Gas, Inc.', 'cluster_id': 1}]
# enter do_inference()
# input_str: {"organization_name": "Analog Devices Inc."},{"organization_name": "Analog Devices, Inc."}
# resp_text: {"organization_name": "Analog Devices, Inc."}
# [{'organization_name': 'Analog Devices, Inc.', 'cluster_id': 2}]
# enter do_inference()
# input_str: {"organization_name": "K.P. Kauffman Company, Inc."},{"organization_name": "K. P. Kauffman Company, Inc."}
# resp_text: {"organization_name": "K.P. Kauffman Company, Inc."}
# [{'organization_name': 'K.P. Kauffman Company, Inc.', 'cluster_id': 3}]
# enter do_inference()
# input_str: {"organization_name": "Neenah Paper Inc."},{"organization_name": "Neenah Paper, Inc."}
# resp_text: {"organization_name": "Neenah Paper, Inc."}
# [{'organization_name': 'Neenah Paper, Inc.', 'cluster_id': 4}]
# enter do_inference()
# input_str: {"organization_name": "PPG Industries, Inc"},{"organization_name": "PPG Industries, Inc."}
# resp_text: {"organization_name": "PPG Industries, Inc."}
# [{'organization_name': 'PPG Industries, Inc.', 'cluster_id': 5}]
# enter do_inference()
# input_str: {"organization_name": "Oklahoma Gas & Electric Co."},{"organization_name": "Oklahoma Gas and Electric Co."}
# resp_text: {"organization_name": "Oklahoma Gas and Electric Co."}
# [{'organization_name': 'Oklahoma Gas and Electric Co.', 'cluster_id': 6}]
# enter do_inference()
# input_str: {"organization_name": "Chevron USA, Inc."},{"organization_name": "Chevron USA Inc."}
# resp_text: {"organization_name": "Chevron USA, Inc."}
# [{'organization_name': 'Chevron USA, Inc.', 'cluster_id': 7}]
# enter do_inference()
# input_str: {"organization_name": "Louisville Gas & Electric Company"},{"organization_name": "Louisville Gas and Electric Company"}
# resp_text: {"organization_name": "Louisville Gas and Electric Company"}
# [{'organization_name': 'Louisville Gas and Electric Company', 'cluster_id': 8}]
# enter do_inference()
# input_str: {"organization_name": "Cargill, Inc"},{"organization_name": "Cargill, Inc."}
# resp_text: {"organization_name": "Cargill, Inc"}
# [{'organization_name': 'Cargill, Inc', 'cluster_id': 9}]
# enter do_inference()
# input_str: {"organization_name": "Dayton Power & Light"},{"organization_name": "Dayton Power and Light"}
# resp_text: {"organization_name": "Dayton Power and Light"}
# [{'organization_name': 'Dayton Power and Light', 'cluster_id': 10}]
# enter do_inference()
# input_str: {"organization_name": "Oklahoma Gas and Electric Company"},{"organization_name": "Oklahoma Gas & Electric Company"}
# resp_text: {"organization_name": "Oklahoma Gas & Electric Company"}
# [{'organization_name': 'Oklahoma Gas & Electric Company', 'cluster_id': 11}]
# enter do_inference()
# input_str: {"organization_name": "Pixelle Specialty Solutions LLC"},{"organization_name": "Pixelle Specialty Solutions, LLC"}
# resp_text: {"organization_name": "Pixelle Specialty Solutions LLC"}
# [{'organization_name': 'Pixelle Specialty Solutions LLC', 'cluster_id': 12}]
# enter do_inference()
# input_str: {"organization_name": "Transcontinental Gas Pipe Line Co., LLC"},{"organization_name": "Transcontinental Gas Pipe Line Company, LLC"}
# resp_text: {"organization_name": "Transcontinental Gas Pipe Line Company, LLC"}
# [{'organization_name': 'Transcontinental Gas Pipe Line Company, LLC', 'cluster_id': 13}]
# enter do_inference()
# input_str: {"organization_name": "Grand Haven Board of Light and Power"},{"organization_name": "Grand Haven Board of Light & Power"}
# resp_text: {"organization_name": "Grand Haven Board of Light and Power"}
# [{'organization_name': 'Grand Haven Board of Light and Power', 'cluster_id': 14}]
# enter do_inference()
# input_str: {"organization_name": "EagleClaw Midstream Ventures, LLC"},{"organization_name": "EagleClaw Midstream Ventures LLC"}
# resp_text: {"organization_name": "EagleClaw Midstream Ventures, LLC"}
# [{'organization_name': 'EagleClaw Midstream Ventures, LLC', 'cluster_id': 15}]
# enter do_inference()
# input_str: {"organization_name": "Kraft Heinz Food Company"},{"organization_name": "Kraft Heinz Foods Company"}
# resp_text: {"organization_name": "Kraft Heinz Foods Company"}
# [{'organization_name': 'Kraft Heinz Foods Company', 'cluster_id': 16}]
# enter do_inference()
# input_str: {"organization_name": "Public Service Electric and Gas Company"},{"organization_name": "Public Service Electric & Gas Company"}
# resp_text: {"organization_name": "Public Service Electric & Gas Company"}
# [{'organization_name': 'Public Service Electric & Gas Company', 'cluster_id': 17}]
# enter do_inference()
# input_str: {"organization_name": "San Diego Gas & Electric"},{"organization_name": "San Diego Gas and Electric"}
# resp_text: {"organization_name": "San Diego Gas & Electric"}
# [{'organization_name': 'San Diego Gas & Electric', 'cluster_id': 18}]
# enter do_inference()
# input_str: {"organization_name": "Dominion Transmission, Inc"},{"organization_name": "Dominion Transmission, Inc."}
# resp_text: {"organization_name": "Dominion Transmission, Inc."}
# [{'organization_name': 'Dominion Transmission, Inc.', 'cluster_id': 19}]
# enter do_inference()
# input_str: {"organization_name": "Republic Services Inc."},{"organization_name": "Republic Services, Inc."}
# resp_text: {"organization_name": "Republic Services, Inc."}
# [{'organization_name': 'Republic Services, Inc.', 'cluster_id': 20}]
# enter do_inference()
# input_str: {"organization_name": "Holcim (US) Inc"},{"organization_name": "Holcim (US) Inc."}
# resp_text: {"organization_name": "Holcim (US) Inc"}
# [{'organization_name': 'Holcim (US) Inc', 'cluster_id': 21}]
# enter do_inference()
# input_str: {"organization_name": "Lamb Weston, Inc"},{"organization_name": "Lamb Weston, Inc."}
# resp_text: {"organization_name": "Lamb Weston, Inc."}
# [{'organization_name': 'Lamb Weston, Inc.', 'cluster_id': 22}]
# enter do_inference()
# input_str: {"organization_name": "Tyson Foods, Inc."},{"organization_name": "Tyson Foods Inc."}
# resp_text: {"organization_name": "Tyson Foods, Inc."}
# [{'organization_name': 'Tyson Foods, Inc.', 'cluster_id': 23}]
# enter do_inference()
# input_str: {"organization_name": "BARGATH, INC"},{"organization_name": "BARGATH, INC."}
# resp_text: {"organization_name": "BARGATH, INC"}
# [{'organization_name': 'BARGATH, INC', 'cluster_id': 24}]
# enter do_inference()
# input_str: {"organization_name": "Vitro S.A.B. de C.V."},{"organization_name": "Vitro, S.A.B. de C.V."}
# resp_text: {"organization_name": "Vitro S.A.B. de C.V."}
# [{'organization_name': 'Vitro S.A.B. de C.V.', 'cluster_id': 25}]
# enter do_inference()
# input_str: {"organization_name": "Enlink Midstream Operating, LP"},{"organization_name": "EnLink Midstream Operating, LP"}
# resp_text: {"organization_name": "EnLink Midstream Operating, LP"}
# [{'organization_name': 'EnLink Midstream Operating, LP', 'cluster_id': 26}]
# enter do_inference()
# input_str: {"organization_name": "E. & J. Gallo Winery"},{"organization_name": "E & J Gallo Winery"}
# resp_text: {"organization_name": "E. & J. Gallo Winery"}
# [{'organization_name': 'E. & J. Gallo Winery', 'cluster_id': 27}]
# enter do_inference()
# input_str: {"organization_name": "Cargill Incorporated"},{"organization_name": "Cargill, Incorporated"}
# resp_text: {"organization_name": "Cargill, Incorporated"}
# [{'organization_name': 'Cargill, Incorporated', 'cluster_id': 28}]
# enter do_inference()
# input_str: {"organization_name": "GOODYEAR TIRE & RUBBER COMPANY"},{"organization_name": "GOODYEAR TIRE AND RUBBER COMPANY"}
# resp_text: {"organization_name": "GOODYEAR TIRE & RUBBER COMPANY"}
# [{'organization_name': 'GOODYEAR TIRE & RUBBER COMPANY', 'cluster_id': 29}]
# enter do_inference()
# input_str: {"organization_name": "Agropur Inc."},{"organization_name": "Agropur, Inc."}
# resp_text: {"organization_name": "Agropur Inc."}
# [{'organization_name': 'Agropur Inc.', 'cluster_id': 30}]
# enter do_inference()
# input_str: {"organization_name": "California Dairies Inc."},{"organization_name": "California Dairies, Inc."}
# resp_text: {"organization_name": "California Dairies, Inc."}
# [{'organization_name': 'California Dairies, Inc.', 'cluster_id': 31}]
# enter do_inference()
# input_str: {"organization_name": "ALLIANCE PIPELINE, L.P."},{"organization_name": "ALLIANCE PIPELINE L.P."}
# resp_text: {"organization_name": "ALLIANCE PIPELINE L.P."}
# [{'organization_name': 'ALLIANCE PIPELINE L.P.', 'cluster_id': 32}]
# enter do_inference()
# input_str: {"organization_name": "Valero Renewable Fuels Company, LLC"},{"organization_name": "Valero Renewable Fuels Company LLC"}
# resp_text: {"organization_name": "Valero Renewable Fuels Company, LLC"}
# [{'organization_name': 'Valero Renewable Fuels Company, LLC', 'cluster_id': 33}]
# enter do_inference()
# input_str: {"organization_name": "ONEOK FIELD SERVICES CO., LLC"},{"organization_name": "ONEOK FIELD SERVICES COMPANY, LLC"}
# resp_text: {"organization_name": "ONEOK FIELD SERVICES COMPANY, LLC"}
# [{'organization_name': 'ONEOK FIELD SERVICES COMPANY, LLC', 'cluster_id': 34}]
# enter do_inference()
# input_str: {"organization_name": "JM Huber Corporation"},{"organization_name": "J.M. Huber Corporation"}
# resp_text: {"organization_name": "J.M. Huber Corporation"}
# [{'organization_name': 'J.M. Huber Corporation', 'cluster_id': 35}]
# enter do_inference()
# input_str: {"organization_name": "COLUMBIA GULF TRANSMISSION CO."},{"organization_name": "COLUMBIA GULF TRANSMISSION CO"}
# resp_text: {"organization_name": "COLUMBIA GULF TRANSMISSION CO"}
# [{'organization_name': 'COLUMBIA GULF TRANSMISSION CO', 'cluster_id': 36}]
# enter do_inference()
# input_str: {"organization_name": "HOLCIM (US) INC"},{"organization_name": "HOLCIM (US) INC."}
# resp_text: {"organization_name": "HOLCIM (US) INC"}
# [{'organization_name': 'HOLCIM (US) INC', 'cluster_id': 37}]
# enter do_inference()
# input_str: {"organization_name": "EOG Resources, Inc."},{"organization_name": "EOG Resources, Inc"}
# resp_text: {"organization_name": "EOG Resources, Inc."}
# [{'organization_name': 'EOG Resources, Inc.', 'cluster_id': 38}]
# enter do_inference()
# input_str: {"organization_name": "ENTERPRISE FIELD SERVICES LLC"},{"organization_name": "ENTERPRISE FIELD SERVICES, LLC"}
# resp_text: {"organization_name": "ENTERPRISE FIELD SERVICES, LLC"}
# [{'organization_name': 'ENTERPRISE FIELD SERVICES, LLC', 'cluster_id': 39}]
# enter do_inference()
# input_str: {"organization_name": "Mosaic Fertilizer, LLC"},{"organization_name": "Mosaic Fertilizer LLC"}
# resp_text: {"organization_name": "Mosaic Fertilizer, LLC"}
# [{'organization_name': 'Mosaic Fertilizer, LLC', 'cluster_id': 40}]
# enter do_inference()
# input_str: {"organization_name": "HILCORP ALASKA, LLC"},{"organization_name": "HILCORP ALASKA LLC"}
# resp_text: {"organization_name": "HILCORP ALASKA LLC"}
# [{'organization_name': 'HILCORP ALASKA LLC', 'cluster_id': 41}]
# enter do_inference()
# input_str: {"organization_name": "ONEOK Field Services, LLC"},{"organization_name": "ONEOK Field Services, L.L.C."}
# resp_text: {"organization_name": "ONEOK Field Services, LLC"}
# [{'organization_name': 'ONEOK Field Services, LLC', 'cluster_id': 42}]
# enter do_inference()
# input_str: {"organization_name": "LLOG Exploration Company, L.L.C."},{"organization_name": "LLOG Exploration Company, LLC"}
# resp_text: {"organization_name": "LLOG Exploration Company, LLC"}
# [{'organization_name': 'LLOG Exploration Company, LLC', 'cluster_id': 43}]
# enter do_inference()
# input_str: {"organization_name": "OWENS-BROCKWAY GLASS CONTAINER INC"},{"organization_name": "OWENS-BROCKWAY GLASS CONTAINER INC."}
# resp_text: {"organization_name": "OWENS-BROCKWAY GLASS CONTAINER INC."}
# [{'organization_name': 'OWENS-BROCKWAY GLASS CONTAINER INC.', 'cluster_id': 44}]
# enter do_inference()
# input_str: {"organization_name": "BP Exploration (Alaska), Inc."},{"organization_name": "BP Exploration (Alaska) Inc."}
# resp_text: {"organization_name": "BP Exploration (Alaska) Inc."}
# [{'organization_name': 'BP Exploration (Alaska) Inc.', 'cluster_id': 45}]
# enter do_inference()
# input_str: {"organization_name": "Gerdau Ameristeel US, Inc"},{"organization_name": "Gerdau Ameristeel US Inc"}
# resp_text: {"organization_name": "Gerdau Ameristeel US Inc"}
# [{'organization_name': 'Gerdau Ameristeel US Inc', 'cluster_id': 46}]
# enter do_inference()
# input_str: {"organization_name": "MERCK SHARP & DOHME CORP."},{"organization_name": "MERCK SHARP & DOHME CORP"}
# resp_text: {"organization_name": "MERCK SHARP & DOHME CORP"}
# [{'organization_name': 'MERCK SHARP & DOHME CORP', 'cluster_id': 47}]
# enter do_inference()
# input_str: {"organization_name": "J.R. Simplot Company"},{"organization_name": "JR Simplot Company"}
# resp_text: {"organization_name": "J.R. Simplot Company"}
# [{'organization_name': 'J.R. Simplot Company', 'cluster_id': 48}]
# enter do_inference()
# input_str: {"organization_name": "Gulf Crossing Pipeline Company LLC"},{"organization_name": "Gulf Crossing Pipeline Company, LLC"}
# resp_text: {"organization_name": "Gulf Crossing Pipeline Company, LLC"}
# [{'organization_name': 'Gulf Crossing Pipeline Company, LLC', 'cluster_id': 49}]
# enter do_inference()
# input_str: {"organization_name": "NRG Energy Inc."},{"organization_name": "NRG Energy, Inc."}
# resp_text: {"organization_name": "NRG Energy, Inc."}
# [{'organization_name': 'NRG Energy, Inc.', 'cluster_id': 50}]
# 100%|██████████| 1/1 [00:00<00:00, 9000.65it/s]
# enter do_inference()
# input_str: {"organization_name": "Kinder Morgan Texas Pipeline, LLC"},{"organization_name": "Kinder Morgan Texas Pipeline LLC"}
# resp_text: {"organization_name": "Kinder Morgan Texas Pipeline LLC"}
# [{'organization_name': 'Kinder Morgan Texas Pipeline LLC', 'cluster_id': 51}]
# enter do_inference()
# input_str: {"organization_name": "Hi-Crush Inc"},{"organization_name": "Hi-Crush Inc."}
# resp_text: {"organization_name": "Hi-Crush Inc."}
# [{'organization_name': 'Hi-Crush Inc.', 'cluster_id': 52}]
# enter do_inference()
# input_str: {"organization_name": "OFS GPRP LLC"},{"organization_name": "OFS GPRP, LLC"}
# resp_text: {"organization_name": "OFS GPRP, LLC"}
# [{'organization_name': 'OFS GPRP, LLC', 'cluster_id': 53}]
# enter do_inference()
# input_str: {"organization_name": "Kinder Morgan Tejas Pipeline, LLC"},{"organization_name": "Kinder Morgan Tejas Pipeline LLC"}
# resp_text: {"organization_name": "Kinder Morgan Tejas Pipeline LLC"}
# [{'organization_name': 'Kinder Morgan Tejas Pipeline LLC', 'cluster_id': 54}]
# enter do_inference()
# input_str: {"organization_name": "Williams Field Services Company, L.L.C."},{"organization_name": "Williams Field Services Company, LLC"}
# resp_text: {"organization_name": "Williams Field Services Company, LLC"}
# [{'organization_name': 'Williams Field Services Company, LLC', 'cluster_id': 55}]
# enter do_inference()
# input_str: {"organization_name": "McWane, Inc."},{"organization_name": "McWane Inc."}
# resp_text: {"organization_name": "McWane Inc."}
# [{'organization_name': 'McWane Inc.', 'cluster_id': 56}]
# enter do_inference()
# input_str: {"organization_name": "XTO ENERGY INC"},{"organization_name": "XTO ENERGY INC."}
# resp_text: {"organization_name": "XTO ENERGY INC"}
# [{'organization_name': 'XTO ENERGY INC', 'cluster_id': 57}]
# enter do_inference()
# input_str: {"organization_name": "Luminant Generation Company, LLC"},{"organization_name": "Luminant Generation Company LLC"}
# resp_text: {"organization_name": "Luminant Generation Company LLC"}
# [{'organization_name': 'Luminant Generation Company LLC', 'cluster_id': 58}]
# enter do_inference()
# input_str: {"organization_name": "COLUMBIA GAS TRANSMISSION LLC"},{"organization_name": "COLUMBIA GAS TRANSMISSION, LLC"}
# resp_text: {"organization_name": "COLUMBIA GAS TRANSMISSION, LLC"}
# [{'organization_name': 'COLUMBIA GAS TRANSMISSION, LLC', 'cluster_id': 59}]
# enter do_inference()
# input_str: {"organization_name": "El Paso Natural Gas Company, L.L.C."},{"organization_name": "El Paso Natural Gas Company, L.P."}
# resp_text: {"organization_name": "El Paso Natural Gas Company"}
# [{'organization_name': 'El Paso Natural Gas Company', 'cluster_id': 60}]
# enter do_inference()
# input_str: {"organization_name": "Starwood Energy Group Global, LLC"},{"organization_name": "Starwood Energy Group Global, L.L.C."}
# resp_text: {"organization_name": "Starwood Energy Group Global, LLC"}
# [{'organization_name': 'Starwood Energy Group Global, LLC', 'cluster_id': 61}]
# enter do_inference()
# input_str: {"organization_name": "Transcontinental Gas Pipe Line Co LLC"},{"organization_name": "Transcontinental Gas Pipe Line Co, LLC"}
# resp_text: {"organization_name": "Transcontinental Gas Pipe Line Co LLC"}
# [{'organization_name': 'Transcontinental Gas Pipe Line Co LLC', 'cluster_id': 62}]
# enter do_inference()
# input_str: {"organization_name": "Lubrizol Corporation"},{"organization_name": "The Lubrizol Corporation"}
# resp_text: {"organization_name": "Lubrizol Corporation"}
# [{'organization_name': 'Lubrizol Corporation', 'cluster_id': 63}]
# enter do_inference()
# input_str: {"organization_name": "TRANSCONTINENTAL GAS PIPE LINE CO LLC"},{"organization_name": "TRANSCONTINENTAL GAS PIPE LINE CO, LLC"}
# resp_text: {"organization_name": "TRANSCONTINENTAL GAS PIPE LINE CO, LLC"}
# [{'organization_name': 'TRANSCONTINENTAL GAS PIPE LINE CO, LLC', 'cluster_id': 64}]
# enter do_inference()
# input_str: {"organization_name": "Solutia Inc"},{"organization_name": "Solutia Inc."}
# resp_text: {"organization_name": "Solutia Inc"}
# [{'organization_name': 'Solutia Inc', 'cluster_id': 65}]
# enter do_inference()
# input_str: {"organization_name": "Leggett & Platt, Incorporated"},{"organization_name": "Leggett & Platt, Inc."}
# resp_text: {"organization_name": "Leggett & Platt, Incorporated"}
# [{'organization_name': 'Leggett & Platt, Incorporated', 'cluster_id': 66}]
# enter do_inference()
# input_str: {"organization_name": "Darling Ingredients Inc."},{"organization_name": "Darling Ingredients Inc"}
# resp_text: {"organization_name": "Darling Ingredients Inc"}
# [{'organization_name': 'Darling Ingredients Inc', 'cluster_id': 67}]
# enter do_inference()
# input_str: {"organization_name": "COLUMBIA GULF TRANSMISSION LLC"},{"organization_name": "COLUMBIA GULF TRANSMISSION, LLC"}
# resp_text: {"organization_name": "COLUMBIA GULF TRANSMISSION, LLC"}
# [{'organization_name': 'COLUMBIA GULF TRANSMISSION, LLC', 'cluster_id': 68}]
# enter do_inference()
# input_str: {"organization_name": "Maritimes & Northeast Pipeline, L.L.C."},{"organization_name": "Maritimes & Northeast Pipeline, LLC"}
# resp_text: {"organization_name": "Maritimes & Northeast Pipeline, LLC"}
# [{'organization_name': 'Maritimes & Northeast Pipeline, LLC', 'cluster_id': 69}]
# enter do_inference()
# input_str: {"organization_name": "Columbia Gas Transmission, LLC"},{"organization_name": "Columbia Gas Transmission LLC"}
# resp_text: {"organization_name": "Columbia Gas Transmission LLC"}
# [{'organization_name': 'Columbia Gas Transmission LLC', 'cluster_id': 70}]
# enter do_inference()
# input_str: {"organization_name": "Targa Midstream Services LLC"},{"organization_name": "Targa Midstream Services, LLC"}
# resp_text: {"organization_name": "Targa Midstream Services, LLC"}
# [{'organization_name': 'Targa Midstream Services, LLC', 'cluster_id': 71}]
# enter do_inference()
# input_str: {"organization_name": "Tennessee Gas Pipeline Company, LLC"},{"organization_name": "Tennessee Gas Pipeline Company, L.L.C."}
# resp_text: {"organization_name": "Tennessee Gas Pipeline Company, LLC"}
# [{'organization_name': 'Tennessee Gas Pipeline Company, LLC', 'cluster_id': 72}]
# enter do_inference()
# input_str: {"organization_name": "Columbia Gulf Transmission, LLC"},{"organization_name": "Columbia Gulf Transmission LLC"}
# resp_text: {"organization_name": "Columbia Gulf Transmission LLC"}
# [{'organization_name': 'Columbia Gulf Transmission LLC', 'cluster_id': 73}]
# enter do_inference()
# input_str: {"organization_name": "TENNESSEE GAS PIPELINE CO, LLC"},{"organization_name": "TENNESSEE GAS PIPELINE CO LLC"}
# resp_text: {"organization_name": "TENNESSEE GAS PIPELINE CO LLC"}
# [{'organization_name': 'TENNESSEE GAS PIPELINE CO LLC', 'cluster_id': 74}]
# enter do_inference()
# input_str: {"organization_name": "The Goodyear Tire & Rubber Company"},{"organization_name": "Goodyear Tire and Rubber Company"}
# resp_text: {"organization_name": "The Goodyear Tire & Rubber Company"}
# [{'organization_name': 'The Goodyear Tire & Rubber Company', 'cluster_id': 75}]
# enter do_inference()
# input_str: {"organization_name": "SOUTHERN NATURAL GAS COMPANY LLC"},{"organization_name": "SOUTHERN NATURAL GAS COMPANY, LLC"}
# resp_text: {"organization_name": "SOUTHERN NATURAL GAS COMPANY, LLC"}
# [{'organization_name': 'SOUTHERN NATURAL GAS COMPANY, LLC', 'cluster_id': 76}]
# enter do_inference()
# input_str: {"organization_name": "FirstEnergy Generation, LLC"},{"organization_name": "FirstEnergy Generation LLC"}
# resp_text: {"organization_name": "FirstEnergy Generation LLC"}
# [{'organization_name': 'FirstEnergy Generation LLC', 'cluster_id': 77}]
# enter do_inference()
# input_str: {"organization_name": "Occidental Petroleum Corp"},{"organization_name": "Occidental Petroleum Corp."}
# resp_text: {"organization_name": "Occidental Petroleum Corp"}
# [{'organization_name': 'Occidental Petroleum Corp', 'cluster_id': 78}]
# enter do_inference()
# input_str: {"organization_name": "Southern Natural Gas Company, L.L.C."},{"organization_name": "Southern Natural Gas Company, LLC"}
# resp_text: {"organization_name": "Southern Natural Gas Company, LLC"}
# [{'organization_name': 'Southern Natural Gas Company, LLC', 'cluster_id': 79}]
# enter do_inference()
# input_str: {"organization_name": "Archer Daniels Midland Co."},{"organization_name": "Archer Daniels Midland Company"}
# resp_text: {"organization_name": "Archer Daniels Midland Company"}
# [{'organization_name': 'Archer Daniels Midland Company', 'cluster_id': 80}]
# enter do_inference()
# input_str: {"organization_name": "Cleco Power LLC"},{"organization_name": "Cleco Power, LLC"}
# resp_text: {"organization_name": "Cleco Power, LLC"}
# [{'organization_name': 'Cleco Power, LLC', 'cluster_id': 81}]
# enter do_inference()
# input_str: {"organization_name": "ARCONIC INC."},{"organization_name": "ARCONIC INC"}
# resp_text: {"organization_name": "ARCONIC INC"}
# [{'organization_name': 'ARCONIC INC', 'cluster_id': 82}]
# enter do_inference()
# input_str: {"organization_name": "Precision Castparts Corp."},{"organization_name": "Precision Castparts Corp"}
# resp_text: {"organization_name": "Precision Castparts Corp"}
# [{'organization_name': 'Precision Castparts Corp', 'cluster_id': 83}]
# enter do_inference()
# input_str: {"organization_name": "Shaw Industries Group Inc."},{"organization_name": "Shaw Industries Group Inc"}
# resp_text: {"organization_name": "Shaw Industries Group Inc"}
# [{'organization_name': 'Shaw Industries Group Inc', 'cluster_id': 84}]
# enter do_inference()
# input_str: {"organization_name": "RG Steel LLC"},{"organization_name": "RG Steel, LLC"}
# resp_text: {"organization_name": "RG Steel, LLC"}
# [{'organization_name': 'RG Steel, LLC', 'cluster_id': 85}]
# enter do_inference()
# input_str: {"organization_name": "Granges Americas Inc."},{"organization_name": "Granges Americas, Inc"}
# resp_text: {"organization_name": "Granges Americas, Inc"}
# [{'organization_name': 'Granges Americas, Inc', 'cluster_id': 86}]
# enter do_inference()
# input_str: {"organization_name": "Midcoast Energy, LLC"},{"organization_name": "Midcoast Energy, L.L.C."}
# resp_text: {"organization_name": "Midcoast Energy, LLC"}
# [{'organization_name': 'Midcoast Energy, LLC', 'cluster_id': 87}]
# enter do_inference()
# input_str: {"organization_name": "The Chemours Company"},{"organization_name": "Chemours Company"}
# resp_text: {"organization_name": "The Chemours Company"}
# [{'organization_name': 'The Chemours Company', 'cluster_id': 88}]
# enter do_inference()
# input_str: {"organization_name": "Sonoco Products Co."},{"organization_name": "Sonoco Products Company"}
# resp_text: {"organization_name": "Sonoco Products Company"}
# [{'organization_name': 'Sonoco Products Company', 'cluster_id': 89}]
# enter do_inference()
# input_str: {"organization_name": "United States Marine Corps"},{"organization_name": "U.S. Marine Corps"}
# resp_text: {"organization_name": "United States Marine Corps"}
# [{'organization_name': 'United States Marine Corps', 'cluster_id': 90}]
# enter do_inference()
# input_str: {"organization_name": "US Gypsum Corporation"},{"organization_name": "US Gypsum Company"}
# resp_text: {"organization_name": "US Gypsum Company"}
# [{'organization_name': 'US Gypsum Company', 'cluster_id': 91}]
# enter do_inference()
# input_str: {"organization_name": "Northern States Power Company"},{"organization_name": "Northern States Power Co."}
# resp_text: {"organization_name": "Northern States Power Company"}
# [{'organization_name': 'Northern States Power Company', 'cluster_id': 92}]
# enter do_inference()
# input_str: {"organization_name": "EC Waste LLC"},{"organization_name": "EC Waste, LLC"}
# resp_text: {"organization_name": "EC Waste, LLC"}
# [{'organization_name': 'EC Waste, LLC', 'cluster_id': 93}]
# enter do_inference()
# input_str: {"organization_name": "Marathon Oil Corporation"},{"organization_name": "Marathon Oil Company"}
# resp_text: {"organization_name": "Marathon Oil Corporation"}
# [{'organization_name': 'Marathon Oil Corporation', 'cluster_id': 94}]
# enter do_inference()
# input_str: {"organization_name": "Air Products & Chemicals Inc."},{"organization_name": "Air Products and Chemicals, Inc."}
# resp_text: {"organization_name": "Air Products and Chemicals, Inc."}
# [{'organization_name': 'Air Products and Chemicals, Inc.', 'cluster_id': 95}]
# enter do_inference()
# input_str: {"organization_name": "ENBRIDGE INC"},{"organization_name": "ENBRIDGE INC."}
# resp_text: {"organization_name": "ENBRIDGE INC."}
# [{'organization_name': 'ENBRIDGE INC.', 'cluster_id': 96}]
# enter do_inference()
# input_str: {"organization_name": "Associated Electric Cooperative Inc."},{"organization_name": "Associated Electric Cooperative, Inc."}
# resp_text: {"organization_name": "Associated Electric Cooperative, Inc."}
# [{'organization_name': 'Associated Electric Cooperative, Inc.', 'cluster_id': 97}]
# enter do_inference()
# input_str: {"organization_name": "WISE ALLOYS LLC"},{"organization_name": "WISE ALLOYS, LLC"}
# resp_text: {"organization_name": "WISE ALLOYS, LLC"}
# [{'organization_name': 'WISE ALLOYS, LLC', 'cluster_id': 98}]
# enter do_inference()
# input_str: {"organization_name": "Arkema Inc."},{"organization_name": "Arkema, Inc."}
# resp_text: {"organization_name": "Arkema Inc."}
# [{'organization_name': 'Arkema Inc.', 'cluster_id': 99}]
# enter do_inference()
# input_str: {"organization_name": "US Department of Energy"},{"organization_name": "United States Department of Energy"}
# resp_text: {"organization_name": "United States Department of Energy"}
# [{'organization_name': 'United States Department of Energy', 'cluster_id': 100}]
# 100%|██████████| 1/1 [00:00<00:00, 10330.80it/s]
# enter do_inference()
# input_str: {"organization_name": "Occidental Petroleum"},{"organization_name": "Occidental Petroleum Corporation"}
# resp_text: {"organization_name": "Occidental Petroleum Corporation"}
# [{'organization_name': 'Occidental Petroleum Corporation', 'cluster_id': 101}]
# enter do_inference()
# input_str: {"organization_name": "COX OIL OFFSHORE, LLC"},{"organization_name": "COX OIL OFFSHORE, L.L.C."}
# resp_text: {"organization_name": "COX OIL OFFSHORE, LLC"}
# [{'organization_name': 'COX OIL OFFSHORE, LLC', 'cluster_id': 102}]
# enter do_inference()
# input_str: {"organization_name": "PANHANDLE EASTERN PIPE LINE COMPANY"},{"organization_name": "PANHANDLE EASTERN PIPE LINE CO"}
# resp_text: {"organization_name": "PANHANDLE EASTERN PIPE LINE COMPANY"}
# [{'organization_name': 'PANHANDLE EASTERN PIPE LINE COMPANY', 'cluster_id': 103}]
# enter do_inference()
# input_str: {"organization_name": "Alcoa Corporation"},{"organization_name": "Alcoa Inc."}
# resp_text: {"organization_name": "Alcoa Corporation"}
# [{'organization_name': 'Alcoa Corporation', 'cluster_id': 104}]
# enter do_inference()
# input_str: {"organization_name": "Enterprise Products Operating LLC"},{"organization_name": "Enterprise Products Operating, LLC"}
# resp_text: {"organization_name": "Enterprise Products Operating LLC"}
# [{'organization_name': 'Enterprise Products Operating LLC', 'cluster_id': 105}]
# enter do_inference()
# input_str: {"organization_name": "South Carolina Electric & Gas Co."},{"organization_name": "South Carolina Electric & Gas Company"}
# resp_text: {"organization_name": "South Carolina Electric & Gas Company"}
# [{'organization_name': 'South Carolina Electric & Gas Company', 'cluster_id': 106}]
# enter do_inference()
# input_str: {"organization_name": "Enbridge Energy Company Inc."},{"organization_name": "Enbridge Energy Company, Inc."}
# resp_text: {"organization_name": "Enbridge Energy Company, Inc."}
# [{'organization_name': 'Enbridge Energy Company, Inc.', 'cluster_id': 107}]
# enter do_inference()
# input_str: {"organization_name": "Dow Chemical Company"},{"organization_name": "The Dow Chemical Company"}
# resp_text: {"organization_name": "The Dow Chemical Company"}
# [{'organization_name': 'The Dow Chemical Company', 'cluster_id': 108}]
# enter do_inference()
# input_str: {"organization_name": "Waste Management Inc."},{"organization_name": "Waste Management, Inc."}
# resp_text: {"organization_name": "Waste Management, Inc."}
# [{'organization_name': 'Waste Management, Inc.', 'cluster_id': 109}]
# enter do_inference()
# input_str: {"organization_name": "Wabash Valley Power Association, Inc."},{"organization_name": "Wabash Valley Power Association"}
# resp_text: {"organization_name": "Wabash Valley Power Association, Inc."}
# [{'organization_name': 'Wabash Valley Power Association, Inc.', 'cluster_id': 110}]
# enter do_inference()
# input_str: {"organization_name": "KINDER MORGAN, INC."},{"organization_name": "KINDER MORGAN INC."}
# resp_text: {"organization_name": "KINDER MORGAN, INC."}
# [{'organization_name': 'KINDER MORGAN, INC.', 'cluster_id': 111}]
# enter do_inference()
# input_str: {"organization_name": "Union Carbide Corp"},{"organization_name": "Union Carbide Corporation"}
# resp_text: {"organization_name": "Union Carbide Corporation"}
# [{'organization_name': 'Union Carbide Corporation', 'cluster_id': 112}]
# enter do_inference()
# input_str: {"organization_name": "COX OIL ONSHORE, LLC"},{"organization_name": "COX OIL ONSHORE, L.L.C."}
# resp_text: {"organization_name": "COX OIL ONSHORE, LLC"}
# [{'organization_name': 'COX OIL ONSHORE, LLC', 'cluster_id': 113}]
# enter do_inference()
# input_str: {"organization_name": "Alaska Village Electric Cooperative"},{"organization_name": "Alaska Village Electric Cooperative, Inc."}
# resp_text: {"organization_name": "Alaska Village Electric Cooperative, Inc."}
# [{'organization_name': 'Alaska Village Electric Cooperative, Inc.', 'cluster_id': 114}]
# enter do_inference()
# input_str: {"organization_name": "DCP Midstream, LP"},{"organization_name": "DCP Midstream Operating, LP"}
# resp_text: {"organization_name": "DCP Midstream, LP"}
# [{'organization_name': 'DCP Midstream, LP', 'cluster_id': 115}]
# enter do_inference()
# input_str: {"organization_name": "Chugach Electric Association, Inc."},{"organization_name": "Chugach Electric Association"}
# resp_text: {"organization_name": "Chugach Electric Association, Inc."}
# [{'organization_name': 'Chugach Electric Association, Inc.', 'cluster_id': 116}]
# enter do_inference()
# input_str: {"organization_name": "Colorado Interstate Gas Co."},{"organization_name": "Colorado Interstate Gas Company"}
# resp_text: {"organization_name": "Colorado Interstate Gas Company"}
# [{'organization_name': 'Colorado Interstate Gas Company', 'cluster_id': 117}]
# enter do_inference()
# input_str: {"organization_name": "Riceland Foods Inc."},{"organization_name": "Riceland Foods, Inc."}
# resp_text: {"organization_name": "Riceland Foods, Inc."}
# [{'organization_name': 'Riceland Foods, Inc.', 'cluster_id': 118}]
# enter do_inference()
# input_str: {"organization_name": "Millennium Pipeline Company, L.L.C."},{"organization_name": "Millennium Pipeline Company LLC"}
# resp_text: {"organization_name": "Millennium Pipeline Company, L.L.C."}
# [{'organization_name': 'Millennium Pipeline Company, L.L.C.', 'cluster_id': 119}]
# enter do_inference()
# input_str: {"organization_name": "ONEOK, Inc."},{"organization_name": "ONEOK, INC."}
# resp_text: {"organization_name": "ONEOK, Inc."}
# [{'organization_name': 'ONEOK, Inc.', 'cluster_id': 120}]
# enter do_inference()
# input_str: {"organization_name": "Minerals Technologies Inc."},{"organization_name": "Mineral Technologies Inc."}
# resp_text: {"organization_name": "Minerals Technologies Inc."}
# [{'organization_name': 'Minerals Technologies Inc.', 'cluster_id': 121}]
# enter do_inference()
# input_str: {"organization_name": "Tennessee Gas Pipeline Co."},{"organization_name": "Tennessee Gas Pipeline Co"}
# resp_text: {"organization_name": "Tennessee Gas Pipeline Co"}
# [{'organization_name': 'Tennessee Gas Pipeline Co', 'cluster_id': 122}]
# enter do_inference()
# input_str: {"organization_name": "Energy XXI GOM, LLC"},{"organization_name": "Energy XXI GOM LLC"}
# resp_text: {"organization_name": "Energy XXI GOM LLC"}
# [{'organization_name': 'Energy XXI GOM LLC', 'cluster_id': 123}]
# enter do_inference()
# input_str: {"organization_name": "U.S. Department of Defense"},{"organization_name": "United States Department of Defense"}
# resp_text: {"organization_name": "United States Department of Defense"}
# [{'organization_name': 'United States Department of Defense', 'cluster_id': 124}]
# enter do_inference()
# input_str: {"organization_name": "United States Air Force"},{"organization_name": "U.S. Air Force"}
# resp_text: {"organization_name": "United States Air Force"}
# [{'organization_name': 'United States Air Force', 'cluster_id': 125}]
# enter do_inference()
# input_str: {"organization_name": "LS POWER DEVELOPMENT, LLC"},{"organization_name": "LS Power Development, LLC"}
# resp_text: {"organization_name": "LS Power Development, LLC"}
# [{'organization_name': 'LS Power Development, LLC', 'cluster_id': 126}]
# enter do_inference()
# input_str: {"organization_name": "AGC Glass Company North America"},{"organization_name": "AGC Glass North America"}
# resp_text: {"organization_name": "AGC Glass North America"}
# [{'organization_name': 'AGC Glass North America', 'cluster_id': 127}]
# enter do_inference()
# input_str: {"organization_name": "Cox Operating, LLC"},{"organization_name": "Cox Operating, L.L.C."}
# resp_text: {"organization_name": "Cox Operating, LLC"}
# [{'organization_name': 'Cox Operating, LLC', 'cluster_id': 128}]
# enter do_inference()
# input_str: {"organization_name": "Entergy Arkansas, Inc."},{"organization_name": "Entergy Arkansas, LLC"}
# resp_text: {"organization_name": "Entergy Arkansas, LLC"}
# [{'organization_name': 'Entergy Arkansas, LLC', 'cluster_id': 129}]
# enter do_inference()
# input_str: {"organization_name": "James Hardie Building Products Inc."},{"organization_name": "James Hardie Building Products, Inc."}
# resp_text: {"organization_name": "James Hardie Building Products Inc."}
# [{'organization_name': 'James Hardie Building Products Inc.', 'cluster_id': 130}]
# enter do_inference()
# input_str: {"organization_name": "ENERGY TRANSFER OPERATING, LP"},{"organization_name": "ENERGY TRANSFER OPERATING, L.P."}
# resp_text: {"organization_name": "Energy Transfer LP"}
# [{'organization_name': 'Energy Transfer LP', 'cluster_id': 131}]
# enter do_inference()
# input_str: {"organization_name": "Sunflower Electric Power Corp."},{"organization_name": "Sunflower Electric Power Corporation"}
# resp_text: {"organization_name": "Sunflower Electric Power Corporation"}
# [{'organization_name': 'Sunflower Electric Power Corporation', 'cluster_id': 132}]
# enter do_inference()
# input_str: {"organization_name": "Oglethorpe Power Corp"},{"organization_name": "Oglethorpe Power Corporation"}
# resp_text: {"organization_name": "Oglethorpe Power Corporation"}
# [{'organization_name': 'Oglethorpe Power Corporation', 'cluster_id': 133}]
# enter do_inference()
# input_str: {"organization_name": "U.S. Sugar Corp."},{"organization_name": "U.S. Sugar Corporation"}
# resp_text: {"organization_name": "U.S. Sugar Corporation"}
# [{'organization_name': 'U.S. Sugar Corporation', 'cluster_id': 134}]
# enter do_inference()
# input_str: {"organization_name": "Vistra Corp"},{"organization_name": "Vistra Corp."}
# resp_text: {"organization_name": "Vistra Corp"}
# [{'organization_name': 'Vistra Corp', 'cluster_id': 135}]
# enter do_inference()
# input_str: {"organization_name": "Southwestern Electric Power Company"},{"organization_name": "Southwestern Electric Power Co"}
# resp_text: {"organization_name": "Southwestern Electric Power Company"}
# [{'organization_name': 'Southwestern Electric Power Company', 'cluster_id': 136}]
# enter do_inference()
# input_str: {"organization_name": "Natural Gas Pipeline Co. of America"},{"organization_name": "Natural Gas Pipeline Company of America"}
# resp_text: {"organization_name": "Natural Gas Pipeline Company of America"}
# [{'organization_name': 'Natural Gas Pipeline Company of America', 'cluster_id': 137}]
# enter do_inference()
# input_str: {"organization_name": "Packaging Corp. of America"},{"organization_name": "Packaging Corporation of America"}
# resp_text: {"organization_name": "Packaging Corporation of America"}
# [{'organization_name': 'Packaging Corporation of America', 'cluster_id': 138}]
# enter do_inference()
# input_str: {"organization_name": "Florida Power & Light"},{"organization_name": "Florida Power & Light Company"}
# resp_text: {"organization_name": "Florida Power & Light Company"}
# [{'organization_name': 'Florida Power & Light Company', 'cluster_id': 139}]
# enter do_inference()
# input_str: {"organization_name": "Graphic Packaging International, Inc."},{"organization_name": "Graphic Packaging International, LLC"}
# resp_text: {"organization_name": "Graphic Packaging International, Inc."}
# [{'organization_name': 'Graphic Packaging International, Inc.', 'cluster_id': 140}]
# enter do_inference()
# input_str: {"organization_name": "Southwestern Public Service Co"},{"organization_name": "Southwestern Public Service Company"}
# resp_text: {"organization_name": "Southwestern Public Service Company"}
# [{'organization_name': 'Southwestern Public Service Company', 'cluster_id': 141}]
# enter do_inference()
# input_str: {"organization_name": "Caterpillar Inc."},{"organization_name": "Caterpillar Inc"}
# resp_text: {"organization_name": "Caterpillar Inc."}
# [{'organization_name': 'Caterpillar Inc.', 'cluster_id': 142}]
# enter do_inference()
# input_str: {"organization_name": "Occidental Permian Ltd"},{"organization_name": "Occidental Permian Ltd."}
# resp_text: {"organization_name": "Occidental Permian Ltd"}
# [{'organization_name': 'Occidental Permian Ltd', 'cluster_id': 143}]
# enter do_inference()
# input_str: {"organization_name": "Los Angeles County Sanitation Districts"},{"organization_name": "Sanitation Districts of Los Angeles County"}
# resp_text: {"organization_name": "Sanitation Districts of Los Angeles County"}
# [{'organization_name': 'Sanitation Districts of Los Angeles County', 'cluster_id': 144}]
# enter do_inference()
# input_str: {"organization_name": "W&T Offshore, Inc."},{"organization_name": "W & T Offshore, Inc."}
# resp_text: {"organization_name": "W&T Offshore, Inc."}
# [{'organization_name': 'W&T Offshore, Inc.', 'cluster_id': 145}]
# enter do_inference()
# input_str: {"organization_name": "EnLink Midstream"},{"organization_name": "Enlink Midstream"}
# resp_text: {"organization_name": "EnLink Midstream"}
# [{'organization_name': 'EnLink Midstream', 'cluster_id': 146}]
# enter do_inference()
# input_str: {"organization_name": "BUNGE NORTH AMERICA, INC."},{"organization_name": "BUNGE NORTH AMERICA INC"}
# resp_text: {"organization_name": "BUNGE NORTH AMERICA, INC."}
# [{'organization_name': 'BUNGE NORTH AMERICA, INC.', 'cluster_id': 147}]
# enter do_inference()
# input_str: {"organization_name": "Chevron Phillips Chemical Company, LP"},{"organization_name": "Chevron Phillips Chemical Company LP"}
# resp_text: {"organization_name": "Chevron Phillips Chemical Company LP"}
# [{'organization_name': 'Chevron Phillips Chemical Company LP', 'cluster_id': 148}]
# enter do_inference()
# input_str: {"organization_name": "BTA OIL PRODUCERS LLC"},{"organization_name": "BTA OIL PRODUCERS, LLC"}
# resp_text: {"organization_name": "BTA OIL PRODUCERS, LLC"}
# [{'organization_name': 'BTA OIL PRODUCERS, LLC', 'cluster_id': 149}]
# enter do_inference()
# input_str: {"organization_name": "BASF CORPORATION"},{"organization_name": "BASF CORP"}
# resp_text: {"organization_name": "BASF CORPORATION"}
# [{'organization_name': 'BASF CORPORATION', 'cluster_id': 150}]
# 100%|██████████| 1/1 [00:00<00:00, 8867.45it/s]
# enter do_inference()
# input_str: {"organization_name": "American Zinc Recycling Corp."},{"organization_name": "American Zinc Recycling Corporation"}
# resp_text: {"organization_name": "American Zinc Recycling Corporation"}
# [{'organization_name': 'American Zinc Recycling Corporation', 'cluster_id': 151}]
# enter do_inference()
# input_str: {"organization_name": "Energy Transfer Operating, LP"},{"organization_name": "Energy Transfer Operating, L.P."}
# resp_text: {"organization_name": "Energy Transfer Operating, L.P."}
# [{'organization_name': 'Energy Transfer Operating, L.P.', 'cluster_id': 152}]
# enter do_inference()
# input_str: {"organization_name": "U.S. Navy"},{"organization_name": "United States Navy"}
# resp_text: {"organization_name": "United States Navy"}
# [{'organization_name': 'United States Navy', 'cluster_id': 153}]
# enter do_inference()
# input_str: {"organization_name": "Rain CII CARBON LLC"},{"organization_name": "RAIN CII CARBON LLC"}
# resp_text: {"organization_name": "Rain CII CARBON LLC"}
# [{'organization_name': 'Rain CII CARBON LLC', 'cluster_id': 154}]
# enter do_inference()
# input_str: {"organization_name": "Gulf South Pipeline Company, LP"},{"organization_name": "Gulf South Pipeline Company, LLC"}
# resp_text: {"organization_name": "Boardwalk Pipeline Partners, LP"}
# [{'organization_name': 'Boardwalk Pipeline Partners, LP', 'cluster_id': 155}]
# enter do_inference()
# input_str: {"organization_name": "Arizona Public Service Company"},{"organization_name": "Arizona Public Service Co"}
# resp_text: {"organization_name": "Arizona Public Service Company"}
# [{'organization_name': 'Arizona Public Service Company', 'cluster_id': 156}]
# enter do_inference()
# input_str: {"organization_name": "Equitrans Midstream Corporation"},{"organization_name": "Equitrans Midstream, L.P."}
# resp_text: {"organization_name": "Equitrans Midstream Corporation"}
# [{'organization_name': 'Equitrans Midstream Corporation', 'cluster_id': 157}]
# enter do_inference()
# input_str: {"organization_name": "Caithness Energy, LLC"},{"organization_name": "Caithness Energy, L.L.C."}
# resp_text: {"organization_name": "Caithness Energy, LLC"}
# [{'organization_name': 'Caithness Energy, LLC', 'cluster_id': 158}]
# enter do_inference()
# input_str: {"organization_name": "Avista Corporation"},{"organization_name": "Avista Corp"}
# resp_text: {"organization_name": "Avista Corporation"}
# [{'organization_name': 'Avista Corporation', 'cluster_id': 159}]
# enter do_inference()
# input_str: {"organization_name": "Armstrong World Industries, Inc."},{"organization_name": "Armstrong World Industries Inc"}
# resp_text: {"organization_name": "Armstrong World Industries, Inc."}
# [{'organization_name': 'Armstrong World Industries, Inc.', 'cluster_id': 160}]
# enter do_inference()
# input_str: {"organization_name": "SOUTHWEST ENERGY CO"},{"organization_name": "SOUTHWESTERN ENERGY CO"}
# resp_text: [{"organization_name": "SOUTHWEST ENERGY CO"}, {"organization_name": "SOUTHWESTERN ENERGY CO"}]
# [{'organization_name': 'SOUTHWEST ENERGY CO', 'cluster_id': 161}, {'organization_name': 'SOUTHWESTERN ENERGY CO', 'cluster_id': 161}]
# enter do_inference()
# input_str: {"organization_name": "TYSON FOODS INCORPORATED"},{"organization_name": "TYSON FOODS INC"}
# resp_text: {"organization_name": "TYSON FOODS INCORPORATED"}
# [{'organization_name': 'TYSON FOODS INCORPORATED', 'cluster_id': 162}]
# enter do_inference()
# input_str: {"organization_name": "AES Corporation"},{"organization_name": "The AES Corporation"}
# resp_text: {"organization_name": "The AES Corporation"}
# [{'organization_name': 'The AES Corporation', 'cluster_id': 163}]
# enter do_inference()
# input_str: {"organization_name": "City of Grand Island Utilities"},{"organization_name": "City of Grand Island Utilities Department"}
# resp_text: {"organization_name": "City of Grand Island Utilities"}
# [{'organization_name': 'City of Grand Island Utilities', 'cluster_id': 164}]
# enter do_inference()
# input_str: {"organization_name": "Evonik Corporation"},{"organization_name": "Evonik Industries"}
# resp_text: {"organization_name": "Evonik Industries"}
# [{'organization_name': 'Evonik Industries', 'cluster_id': 165}]
# enter do_inference()
# input_str: {"organization_name": "U.S. Army"},{"organization_name": "United States Army"}
# resp_text: {"organization_name": "United States Army"}
# [{'organization_name': 'United States Army', 'cluster_id': 166}]
# enter do_inference()
# input_str: {"organization_name": "Louisiana Pacific Corporation"},{"organization_name": "Louisiana-Pacific Corporation"}
# resp_text: {"organization_name": "Louisiana-Pacific Corporation"}
# [{'organization_name': 'Louisiana-Pacific Corporation', 'cluster_id': 167}]
# enter do_inference()
# input_str: {"organization_name": "W&T OFFSHORE, INC."},{"organization_name": "W&T OFFSHORE INC."}
# resp_text: {"organization_name": "W&T OFFSHORE, INC."}
# [{'organization_name': 'W&T OFFSHORE, INC.', 'cluster_id': 168}]
# enter do_inference()
# input_str: {"organization_name": "KERN RIVER GAS TRANSMISSION COMPANY"},{"organization_name": "KERN RIVER GAS TRANSMISSION CO"}
# resp_text: {"organization_name": "KERN RIVER GAS TRANSMISSION COMPANY"}
# [{'organization_name': 'KERN RIVER GAS TRANSMISSION COMPANY', 'cluster_id': 169}]
# enter do_inference()
# input_str: {"organization_name": "ExxonMobil Oil Corporation"},{"organization_name": "Exxon Mobil Corporation"}
# resp_text: {"organization_name": "Exxon Mobil Corporation"}
# [{'organization_name': 'Exxon Mobil Corporation', 'cluster_id': 170}]
# enter do_inference()
# input_str: {"organization_name": "MISSISSIPPI LIME CO"},{"organization_name": "MISSISSIPPI LIME COMPANY"}
# resp_text: {"organization_name": "MISSISSIPPI LIME COMPANY"}
# [{'organization_name': 'MISSISSIPPI LIME COMPANY', 'cluster_id': 171}]
# enter do_inference()
# input_str: {"organization_name": "Boardwalk Pipelines, LP"},{"organization_name": "Boardwalk Pipeline Partners, LP"}
# resp_text: {"organization_name": "Boardwalk Pipeline Partners, LP"}
# [{'organization_name': 'Boardwalk Pipeline Partners, LP', 'cluster_id': 172}]
# enter do_inference()
# input_str: {"organization_name": "Mississippi Power Company"},{"organization_name": "Mississippi Power Co"}
# resp_text: {"organization_name": "Mississippi Power Company"}
# [{'organization_name': 'Mississippi Power Company', 'cluster_id': 173}]
# enter do_inference()
# input_str: {"organization_name": "ANR PIPELINE CO"},{"organization_name": "ANR PIPELINE COMPANY"}
# resp_text: {"organization_name": "ANR PIPELINE COMPANY"}
# [{'organization_name': 'ANR PIPELINE COMPANY', 'cluster_id': 174}]
# enter do_inference()
# input_str: {"organization_name": "THE WILLIAMS COMPANIES, INC."},{"organization_name": "WILLIAMS COMPANIES, INC."}
# resp_text: {"organization_name": "WILLIAMS COMPANIES, INC."}
# [{'organization_name': 'WILLIAMS COMPANIES, INC.', 'cluster_id': 175}]
# enter do_inference()
# input_str: {"organization_name": "GenOn Energy Inc."},{"organization_name": "GenOn Energy, Inc."}
# resp_text: {"organization_name": "GenOn Energy, Inc."}
# [{'organization_name': 'GenOn Energy, Inc.', 'cluster_id': 176}]
# enter do_inference()
# input_str: {"organization_name": "ADVANSIX INCORPORATED"},{"organization_name": "ADVANSIX INC"}
# resp_text: {"organization_name": "ADVANSIX INC"}
# [{'organization_name': 'ADVANSIX INC', 'cluster_id': 177}]
# enter do_inference()
# input_str: {"organization_name": "Targa Resources Corporation"},{"organization_name": "Targa Resources Corp."}
# resp_text: {"organization_name": "Targa Resources Corp."}
# [{'organization_name': 'Targa Resources Corp.', 'cluster_id': 178}]
# enter do_inference()
# input_str: {"organization_name": "Cenovus Energy Inc."},{"organization_name": "Cenovus Energy"}
# ...
# input_str: {"organization_name": "RAYONIER PERFORMANCE FIBERS LLC"},{"organization_name": "Rayonier Performance Fibers LLC"}
# resp_text: {"organization_name": "Rayonier Performance Fibers LLC"}
# [{'organization_name': 'Rayonier Performance Fibers LLC', 'cluster_id': 448}]
# enter do_inference()
# input_str: {"organization_name": "SunCoke Energy, Inc."},{"organization_name": "SunCoke Energy"}
# resp_text: {"organization_name": "SunCoke Energy, Inc."}
# [{'organization_name': 'SunCoke Energy, Inc.', 'cluster_id': 449}]
# enter do_inference()
# input_str: {"organization_name": "Invenergy"},{"organization_name": "Invenergy LLC"}
# resp_text: {"organization_name": "Invenergy LLC"}
# [{'organization_name': 'Invenergy LLC', 'cluster_id': 450}]
# enter do_inference()
# input_str: {"organization_name": "ARAUCO-USA LLC"},{"organization_name": "ARAUCO NORTH AMERICA, INC"}
# resp_text: {"organization_name": "ARAUCO NORTH AMERICA, INC"}
# [{'organization_name': 'ARAUCO NORTH AMERICA, INC', 'cluster_id': 451}]
# enter do_inference()
# input_str: {"organization_name": "NewYork-Presbyterian Healthcare System"},{"organization_name": "NewYork-Presbyterian"}
# resp_text: {"organization_name": "NewYork-Presbyterian Healthcare System"}
# [{'organization_name': 'NewYork-Presbyterian Healthcare System', 'cluster_id': 452}]
# enter do_inference()
# input_str: {"organization_name": "Buzzi Unicem USA"},{"organization_name": "BUZZI UNICEM USA"}
# resp_text: {"organization_name": "Buzzi Unicem USA"}
# [{'organization_name': 'Buzzi Unicem USA', 'cluster_id': 453}]
# enter do_inference()
# input_str: {"organization_name": "Dominion Energy Transmission"},{"organization_name": "Dominion Energy Transmission, Inc."}
# resp_text: {"organization_name": "Dominion Energy Transmission, Inc."}
# [{'organization_name': 'Dominion Energy Transmission, Inc.', 'cluster_id': 454}]
# enter do_inference()
# input_str: {"organization_name": "Koppers Holdings Inc."},{"organization_name": "Koppers Inc."}
# resp_text: {"organization_name": "Koppers Holdings Inc."}
# [{'organization_name': 'Koppers Holdings Inc.', 'cluster_id': 455}]
# enter do_inference()
# input_str: {"organization_name": "BRIDGESTONE AMERICAS, INC."},{"organization_name": "BRIDGESTONE AMERICAS"}
# resp_text: {"organization_name": "BRIDGESTONE AMERICAS"}
# [{'organization_name': 'BRIDGESTONE AMERICAS', 'cluster_id': 456}]
# enter do_inference()
# input_str: {"organization_name": "Gulfport Energy Corporation"},{"organization_name": "GULFPORT ENERGY CORPORATION"}
# resp_text: {"organization_name": "Gulfport Energy Corporation"}
# [{'organization_name': 'Gulfport Energy Corporation', 'cluster_id': 457}]
# enter do_inference()
# input_str: {"organization_name": "FirstEnergy"},{"organization_name": "FirstEnergy Corporation"}
# resp_text: {"organization_name": "FirstEnergy Corporation"}
# [{'organization_name': 'FirstEnergy Corporation', 'cluster_id': 458}]
# enter do_inference()
# input_str: {"organization_name": "Lehigh Hanson, Inc."},{"organization_name": "Lehigh Hanson"}
# resp_text: {"organization_name": "Lehigh Hanson"}
# [{'organization_name': 'Lehigh Hanson', 'cluster_id': 459}]
# enter do_inference()
# input_str: {"organization_name": "California Resources Production Corporation"},{"organization_name": "California Resources Corporation"}
# resp_text: {"organization_name": "California Resources Corporation"}
# [{'organization_name': 'California Resources Corporation', 'cluster_id': 460}]
# enter do_inference()
# input_str: {"organization_name": "CALUMET LUBRICANTS CO LP"},{"organization_name": "Calumet Lubricants Co. LP"}
# resp_text: {"organization_name": "Calumet Lubricants Co. LP"}
# [{'organization_name': 'Calumet Lubricants Co. LP', 'cluster_id': 461}]
# enter do_inference()
# input_str: {"organization_name": "GUARDIAN INDUSTRIES CORP"},{"organization_name": "Guardian Industries Corp."}
# resp_text: {"organization_name": "Guardian Industries Corp."}
# [{'organization_name': 'Guardian Industries Corp.', 'cluster_id': 462}]
# enter do_inference()
# input_str: {"organization_name": "Southern Company Gas"},{"organization_name": "Southern Natural Gas Company"}
# resp_text: {"organization_name": "Southern Company Gas"}
# [{'organization_name': 'Southern Company Gas', 'cluster_id': 463}]
# enter do_inference()
# input_str: {"organization_name": "Weyerhaeuser NR Company"},{"organization_name": "Weyerhaeuser Company"}
# resp_text: {"organization_name": "Weyerhaeuser Company"}
# [{'organization_name': 'Weyerhaeuser Company', 'cluster_id': 464}]
# enter do_inference()
# input_str: {"organization_name": "PIONEER NATURAL RESOURCES USA, INC."},{"organization_name": "Pioneer Natural Resources USA, Inc."}
# resp_text: {"organization_name": "Pioneer Natural Resources USA, Inc."}
# [{'organization_name': 'Pioneer Natural Resources USA, Inc.', 'cluster_id': 465}]
# enter do_inference()
# input_str: {"organization_name": "Greenleaf Power, LLC"},{"organization_name": "GREENLEAF ENERGY, LLC"}
# resp_text: {"organization_name": "GREENLEAF ENERGY, LLC"}
# [{'organization_name': 'GREENLEAF ENERGY, LLC', 'cluster_id': 466}]
# enter do_inference()
# input_str: {"organization_name": "Heidelberg Materials US"},{"organization_name": "Heidelberg Materials"}
# resp_text: {"organization_name": "Heidelberg Materials"}
# [{'organization_name': 'Heidelberg Materials', 'cluster_id': 467}]
# enter do_inference()
# input_str: {"organization_name": "University of Kansas"},{"organization_name": "Kansas State University"}
# resp_text: {"organization_name": "Kansas Board of Regents"}
# [{'organization_name': 'Kansas Board of Regents', 'cluster_id': 468}]
# enter do_inference()
# input_str: {"organization_name": "Marquis Energy"},{"organization_name": "MARQUIS ENERGY LLC"}
# resp_text: {"organization_name": "MARQUIS ENERGY LLC"}
# [{'organization_name': 'MARQUIS ENERGY LLC', 'cluster_id': 469}]
# enter do_inference()
# input_str: {"organization_name": "AltaGas"},{"organization_name": "AltaGas Ltd."}
# resp_text: {"organization_name": "AltaGas Ltd."}
# [{'organization_name': 'AltaGas Ltd.', 'cluster_id': 470}]
# enter do_inference()
# input_str: {"organization_name": "Anheuser-Busch InBev"},{"organization_name": "Anheuser-Busch"}
# resp_text: {"organization_name": "Anheuser-Busch InBev"}
# [{'organization_name': 'Anheuser-Busch InBev', 'cluster_id': 471}]
# enter do_inference()
# input_str: {"organization_name": "Talen Energy"},{"organization_name": "Talen Energy Corporation"}
# resp_text: {"organization_name": "Talen Energy Corporation"}
# [{'organization_name': 'Talen Energy Corporation', 'cluster_id': 472}]
# enter do_inference()
# input_str: {"organization_name": "Wisconsin Public Service Corporation"},{"organization_name": "Wisconsin Public Service"}
# resp_text: {"organization_name": "Wisconsin Public Service Corporation"}
# [{'organization_name': 'Wisconsin Public Service Corporation', 'cluster_id': 473}]
# enter do_inference()
# input_str: {"organization_name": "Shell Chemical Co."},{"organization_name": "Shell Chemical LP"}
# resp_text: {"organization_name": "Shell Chemical LP"}
# [{'organization_name': 'Shell Chemical LP', 'cluster_id': 474}]
# enter do_inference()
# input_str: {"organization_name": "Alabama Power Company"},{"organization_name": "Alabama Power"}
# resp_text: {"organization_name": "Alabama Power Company"}
# [{'organization_name': 'Alabama Power Company', 'cluster_id': 475}]
# enter do_inference()
# input_str: {"organization_name": "Stellantis"},{"organization_name": "Stellantis US LLC"}
# resp_text: {"organization_name": "Stellantis"}
# [{'organization_name': 'Stellantis', 'cluster_id': 476}]
# enter do_inference()
# input_str: {"organization_name": "Koch Fertilizer, LLC"},{"organization_name": "Koch Fertilizer"}
# resp_text: {"organization_name": "Koch Fertilizer"}
# [{'organization_name': 'Koch Fertilizer', 'cluster_id': 477}]
# enter do_inference()
# input_str: {"organization_name": "American Electric Power (AEP)"},{"organization_name": "American Electric Power"}
# resp_text: {"organization_name": "American Electric Power"}
# [{'organization_name': 'American Electric Power', 'cluster_id': 478}]
# enter do_inference()
# input_str: {"organization_name": "Baxter International Inc."},{"organization_name": "Baxter Healthcare"}
# resp_text: {"organization_name": "Baxter International Inc."}
# [{'organization_name': 'Baxter International Inc.', 'cluster_id': 479}]
# enter do_inference()
# input_str: {"organization_name": "United States Steel Corporation"},{"organization_name": "US Steel"}
# resp_text: {"organization_name": "United States Steel Corporation"}
# [{'organization_name': 'United States Steel Corporation', 'cluster_id': 480}]
# enter do_inference()
# input_str: {"organization_name": "MillerCoors LLC"},{"organization_name": "MillerCoors"}
# resp_text: {"organization_name": "MillerCoors"}
# [{'organization_name': 'MillerCoors', 'cluster_id': 481}]
# enter do_inference()
# input_str: {"organization_name": "West Fraser"},{"organization_name": "West Fraser, Inc."}
# resp_text: {"organization_name": "West Fraser, Inc."}
# [{'organization_name': 'West Fraser, Inc.', 'cluster_id': 482}]
# enter do_inference()
# input_str: {"organization_name": "Westlake Chemical Corporation"},{"organization_name": "Westlake Petrochemicals LP"}
# resp_text: {"organization_name": "Westlake Chemical Corporation"}
# [{'organization_name': 'Westlake Chemical Corporation', 'cluster_id': 483}]
# enter do_inference()
# input_str: {"organization_name": "Waste Connections"},{"organization_name": "Waste Connections, Inc."}
# resp_text: {"organization_name": "Waste Connections, Inc."}
# [{'organization_name': 'Waste Connections, Inc.', 'cluster_id': 484}]
# enter do_inference()
# input_str: {"organization_name": "Amgen Inc."},{"organization_name": "AMGEN INC"}
# resp_text: {"organization_name": "Amgen Inc."}
# [{'organization_name': 'Amgen Inc.', 'cluster_id': 485}]
# enter do_inference()
# input_str: {"organization_name": "Montgomery County, Virginia"},{"organization_name": "Montgomery County"}
# resp_text: {"organization_name": "Montgomery County, Virginia"}
# [{'organization_name': 'Montgomery County, Virginia', 'cluster_id': 486}]
# enter do_inference()
# input_str: {"organization_name": "Kimberly-Clark Corporation"},{"organization_name": "KIMBERLY-CLARK CORPORATION"}
# resp_text: {"organization_name": "Kimberly-Clark Corporation"}
# [{'organization_name': 'Kimberly-Clark Corporation', 'cluster_id': 487}]
# enter do_inference()
# input_str: {"organization_name": "Boardwalk Pipelines"},{"organization_name": "Boardwalk Pipeline Partners"}
# resp_text: {"organization_name": "Boardwalk Pipeline Partners"}
# [{'organization_name': 'Boardwalk Pipeline Partners', 'cluster_id': 488}]
# enter do_inference()
# input_str: {"organization_name": "Linde Inc"},{"organization_name": "Linde"}
# resp_text: {"organization_name": "Linde"}
# [{'organization_name': 'Linde', 'cluster_id': 489}]
# enter do_inference()
# input_str: {"organization_name": "Vistra Energy"},{"organization_name": "Vistra Energy Corp."}
# resp_text: {"organization_name": "Vistra Energy Corp."}
# [{'organization_name': 'Vistra Energy Corp.', 'cluster_id': 490}]
# enter do_inference()
# input_str: {"organization_name": "Kentucky Utilities"},{"organization_name": "Kentucky Utilities Company"}
# resp_text: {"organization_name": "Kentucky Utilities Company"}
# [{'organization_name': 'Kentucky Utilities Company', 'cluster_id': 491}]
# enter do_inference()
# input_str: {"organization_name": "Core Energy"},{"organization_name": "Core Energy, LLC"}
# resp_text: {"organization_name": "Core Energy, LLC"}
# [{'organization_name': 'Core Energy, LLC', 'cluster_id': 492}]
# enter do_inference()
# input_str: {"organization_name": "TC Energy Corporation"},{"organization_name": "TC Energy"}
# resp_text: {"organization_name": "TC Energy Corporation"}
# [{'organization_name': 'TC Energy Corporation', 'cluster_id': 493}]
# enter do_inference()
# input_str: {"organization_name": "HF Sinclair Corporation"},{"organization_name": "HF Sinclair"}
# resp_text: {"organization_name": "HF Sinclair Corporation"}
# [{'organization_name': 'HF Sinclair Corporation', 'cluster_id': 494}]
# enter do_inference()
# input_str: {"organization_name": "Hood Container Corporation"},{"organization_name": "Hood Packaging Corporation"}
# resp_text: {"organization_name": "Hood Companies, Inc."}
# [{'organization_name': 'Hood Companies, Inc.', 'cluster_id': 495}]
# 100%|██████████| 1/1 [00:00<00:00, 6069.90it/s]
# enter do_inference()
# input_str: {"organization_name": "Wisconsin Electric Power Company"},{"organization_name": "Wisconsin Power and Light Company"}
# resp_text: {"organization_name": "WEC Energy Group"}
# [{'organization_name': 'WEC Energy Group', 'cluster_id': 496}]
# enter do_inference()
# input_str: {"organization_name": "Evergy, Inc."},{"organization_name": "Evergy"}
# resp_text: {"organization_name": "Evergy, Inc."}
# [{'organization_name': 'Evergy, Inc.', 'cluster_id': 497}]
# enter do_inference()
# input_str: {"organization_name": "Northwest Pipeline GP"},{"organization_name": "NORTHWEST PIPELINE GP"}
# resp_text: {"organization_name": "Northwest Pipeline GP"}
# [{'organization_name': 'Northwest Pipeline GP', 'cluster_id': 498}]
# enter do_inference()
# input_str: {"organization_name": "Grede LLC"},{"organization_name": "Grede Holdings LLC"}
# resp_text: {"organization_name": "Grede Holdings LLC"}
# [{'organization_name': 'Grede Holdings LLC', 'cluster_id': 499}]
# enter do_inference()
# input_str: {"organization_name": "DeKalb County Government"},{"organization_name": "DeKalb County"}
# resp_text: {"organization_name": "DeKalb County"}
# [{'organization_name': 'DeKalb County', 'cluster_id': 500}]
# enter do_inference()
# input_str: {"organization_name": "Oryx Midstream Services II, LLC"},{"organization_name": "Oryx Midstream Services"}
# resp_text: {"organization_name": "Oryx Midstream Services"}
# [{'organization_name': 'Oryx Midstream Services', 'cluster_id': 501}]
# enter do_inference()
# input_str: {"organization_name": "Giampaolo Group Inc."},{"organization_name": "Giampaolo Group"}
# resp_text: {"organization_name": "Giampaolo Group"}
# [{'organization_name': 'Giampaolo Group', 'cluster_id': 502}]
# enter do_inference()
# input_str: {"organization_name": "Oxbow Corporation"},{"organization_name": "Oxbow Group"}
# resp_text: {"organization_name": "Oxbow Group"}
# [{'organization_name': 'Oxbow Group', 'cluster_id': 503}]
# enter do_inference()
# input_str: {"organization_name": "Kinetik Holdings LP"},{"organization_name": "Kinetik Holdings, Inc."}
# resp_text: {"organization_name": "Kinetik Holdings LP"}
# [{'organization_name': 'Kinetik Holdings LP', 'cluster_id': 504}]
# enter do_inference()
# input_str: {"organization_name": "GENERAL MILLS INC."},{"organization_name": "GENERAL MILLS"}
# resp_text: {"organization_name": "GENERAL MILLS INC."}
# [{'organization_name': 'GENERAL MILLS INC.', 'cluster_id': 505}]
# enter do_inference()
# input_str: {"organization_name": "Jackson County"},{"organization_name": "County of Jackson"}
# resp_text: {"organization_name": "County of Jackson"}
# [{'organization_name': 'County of Jackson', 'cluster_id': 506}]
# enter do_inference()
# input_str: {"organization_name": "CITY OF INDEPENDENCE, MISSOURI"},{"organization_name": "City of Independence, Missouri"}
# resp_text: {"organization_name": "City of Independence, Missouri"}
# [{'organization_name': 'City of Independence, Missouri', 'cluster_id': 507}]
# enter do_inference()
# input_str: {"organization_name": "Washington State University"},{"organization_name": "Western Washington University"}
# resp_text: [{"organization_name": "Washington State University"}, {"organization_name": "Western Washington University"}]
# [{'organization_name': 'Washington State University', 'cluster_id': 508}, {'organization_name': 'Western Washington University', 'cluster_id': 508}]
# enter do_inference()
# input_str: {"organization_name": "PACIFICORP"},{"organization_name": "PacifiCorp"}
# resp_text: {"organization_name": "PacifiCorp"}
# [{'organization_name': 'PacifiCorp', 'cluster_id': 509}]
# enter do_inference()
# input_str: {"organization_name": "LG&E and KU Services Company"},{"organization_name": "LG&E and KU Energy LLC"}
# resp_text: {"organization_name": "LG&E and KU Energy LLC"}
# [{'organization_name': 'LG&E and KU Energy LLC', 'cluster_id': 510}]
# 100%|██████████| 1/1 [00:00<00:00, 754.51it/s]

# %%
# %%bigquery
# alter table `us_climate_fin.ghg_org_name_filtered`
# drop column cluster_id
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from us_climate_fin.ghg_org_name_filtered
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                              organization_name
# 0                  Kaiser Aluminum Corporation
# 1                            Perdue Farms Inc.
# 2              Martin Marietta Materials, Inc.
# 3    Total Petrochemicals & Refining USA, Inc.
# 4                           JR SIMPLOT COMPANY
# ..                                         ...
# 511                     Waste Management, Inc.
# 512                  Western Sugar Cooperative
# 513       Williams Field Services Company, LLC
# 514                             XTO ENERGY INC
# 515                            XTO Energy Inc.
#
# [516 rows x 1 columns]

# %% [markdown]
# Compute the list of organization names to discard

# %%
# %%bigquery
# create or replace table us_climate_fin.ghg_org_name_discard as
#     select organization_name from us_climate_fin.ghg_org_clusters
#     except distinct
#     select organization_name from us_climate_fin.ghg_org_name_filtered
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select * from us_climate_fin.ghg_org_name_discard
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                          organization_name
# 0                       E & J Gallo Winery
# 1           COLUMBIA GULF TRANSMISSION CO.
# 2     Starwood Energy Group Global, L.L.C.
# 3    TRANSCONTINENTAL GAS PIPE LINE CO LLC
# 4                          WISE ALLOYS LLC
# ..                                     ...
# 509   Formosa Plastics Corporation, U.S.A.
# 510                            Duke Energy
# 511                                 Solvay
# 512                                PepsiCo
# 513           GOLDEN VALLEY ELECTRIC ASSOC
#
# [514 rows x 1 columns]

# %% [markdown]
# ### Part 7: Construct the final ghg organization table

# %%
# %%bigquery
# create or replace table us_climate_fin.ghg_organization_final as
#     select * from us_climate_fin.ghg_org_names_raw
#     where organization_name not in (select organization_name from us_climate_fin.ghg_org_name_discard)
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# Check for duplicates, however this is not an accurate way to check for actual duplicates in this data since our duplicates will have slight differences.

# %%
# %%bigquery
# select organization_name, count(*) as count
# from us_climate_fin.ghg_organization_final
# group by organization_name
# having count(*) > 1
# Out:
# Query is running:   0%|          |
# Downloading: |          |
# Empty DataFrame
# Columns: [organization_name, count]
# Index: []

# %% [markdown]
# ### Part 8: Conclusion

# %% [markdown]
# We built an embedding approach to normalize GHG organization names in our dataset. Our pipeline began by generating embeddings and identifying organization name pairs with high similarity using cosine distance. We then filtered those with distances ≤ 0.075 and grouped them into clusters, each assumed to represent a single entity.
#
# To resolve which organization name to retain from each cluster, we used a large language model (LLM) to evaluate the names and return the most representative one. This method allowed us to capture duplicates that traditional string-matching techniques would have missed, especially when variations involved abbreviations, suffixes, or inconsistent formatting. The final output was a cleaned list of distinct organization names suitable for downstream analysis.
#
# Previously, we used an LLM to directly normalize organization names by inferring the most canonical form from raw inputs. This approach was quite effective in many cases, especially for subtle variations in naming. In this project, we explored a complementary method by using text embeddings and cosine distance to pair organization names that are likely duplicates. This let us group similar names before invoking the LLM. However, to ensure reasonable recall, we had to use a relatively large distance threshold, which introduced some false positives and still missed a few known duplicates. Moving forward, our plan is to link these normalized organization names back to their corresponding facility IDs and integrate them into emissions datasets.
